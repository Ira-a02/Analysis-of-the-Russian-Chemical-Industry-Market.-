# %%
import pandas as pd
import numpy as np

# %%
FOLDER_PATH = '/Users/artemzmailov/Desktop/Chemical_Industry_Project/'

# %%
data = pd.read_csv(FOLDER_PATH + 'first_7_files.csv')

# %%
all_categories_mapping = {
    # Газы и газовые смеси
    'Технические газы': 'Газы и газовые смеси',
    'Медицинские газы': 'Газы и газовые смеси',
    'Особо чистые газы': 'Газы и газовые смеси',
    'Газовые смеси пищевые': 'Газы и газовые смеси',
    'Газы': 'Газы и газовые смеси',
    'Жидкие газы': 'Газы и газовые смеси',
    'Смеси сварочные': 'Газы и газовые смеси',
    'Смеси пищевые': 'Газы и газовые смеси',
    'Смеси лазерные': 'Газы и газовые смеси',
    'Смеси для стерилизации': 'Газы и газовые смеси',
    'Смеси медицинского назначения': 'Газы и газовые смеси',
    'Смеси Технические (ТГС)': 'Газы и газовые смеси',
    'Смеси эксимерные': 'Газы и газовые смеси',
    
    # Сварочные материалы и оборудование
    'Припои': 'Сварочные материалы и оборудование',
    'Электроды': 'Сварочные материалы и оборудование',
    'Проволока': 'Сварочные материалы и оборудование',
    'Стальные пропановые баллоны': 'Сварочные материалы и оборудование',
    'Газификаторы горизонтального типа': 'Сварочные материалы и оборудование',
    'Газификаторы вертикального типа': 'Сварочные материалы и оборудование',
    
    # Клеи и строительные смеси
    'Универсальные ПВА клеи': 'Клеи и строительные смеси',
    'Клеи паркетные и специальные': 'Клеи и строительные смеси',
    'Клеи для обоев': 'Клеи и строительные смеси',
    'Плиточные клеи для влажных помещений': 'Клеи и строительные смеси',
    'Кладочно-клеевые растворы': 'Клеи и строительные смеси',
    'Клей для искусственной травы': 'Клеи и строительные смеси',
    'Дисперсионные клеи': 'Клеи и строительные смеси',
    'Клеи для напольных покрытий': 'Клеи и строительные смеси',
    'Шпаклевки': 'Клеи и строительные смеси',
    'Затирки': 'Клеи и строительные смеси',
    'Наливные полы': 'Клеи и строительные смеси',
    'Грунтовки': 'Клеи и строительные смеси',
    'Праймеры': 'Клеи и строительные смеси',
    'Гидроизоляционные праймеры': 'Клеи и строительные смеси',
    'Гидроизоляционные мастики': 'Клеи и строительные смеси',
    'Штукатурки': 'Клеи и строительные смеси',
    
    # Герметики
    'Силиконовые герметики': 'Герметики',
    'Акриловые герметики': 'Герметики',
    'Гибридные герметики': 'Герметики',
    
    # Промышленные технологии и клеи
    'Конструкционное склеивание': 'Промышленные технологии',
    'Клеи-расплавы': 'Промышленные технологии',
    'Клеи-расплавы для полиграфии': 'Промышленные технологии',
    'Склеивание массива древесины': 'Промышленные технологии',
    'Каширование': 'Промышленные технологии',
    'Вклейка окошек': 'Промышленные технологии',
    'Ламинация плит полимерными пленками': 'Промышленные технологии',
    'Ламинация картона полимерными пленками': 'Промышленные технологии',
    'Деревообрабатывающая промышленность': 'Промышленные технологии',
    'Производство сэндвич-панелей для автофургонов и спецтехники': 'Промышленные технологии',
    'Производство промышленных фильтров': 'Промышленные технологии',
    'Упаковочная промышленность': 'Промышленные технологии',
    'Упрочняющие ленты': 'Промышленные технологии',
    
    # Косметика
    'Косметика для лица': 'Косметика',
    'Косметика для тела': 'Косметика',
    'Косметика для волос': 'Косметика',
    'Косметика комплексные решения': 'Косметика',
    'Косметика подарки': 'Косметика',
    'Косметика для него': 'Косметика',
    'Косметика ароматерапия': 'Косметика',
    'Дополнительные средства для ухода за плиткой и швами': 'Косметика',
    
    # Специальные решения
    'Система для токопроводящих покрытий': np.nan,
    'Аксессуары': np.nan,
    'Вся продукция': np.nan,
    'Продукция для промышленности': np.nan}

def data_category_change(item):
    if pd.isna(item):
        return np.nan
    if item not in all_categories_mapping:
        return item
    return all_categories_mapping[item]
data['Категория'] = data['Категория'].apply(data_category_change)

# %%
data['Категория'].unique()
# Out:
# array(['Газы и газовые смеси', 'Промышленные технологии', 'Косметика',
#        'Герметики', 'Клеи и строительные смеси', nan,
#        'Сварочные материалы и оборудование'], dtype=object)

# %%
data.loc[data['Категория'].isna()]
# Out:
#         Компания Категория                                   Название товара  \
# 78         КЕСТО       NaN                                 Kesto Master Flis
# 94         КЕСТО       NaN                            Отвердитель Hardener M
# 106        КЕСТО       NaN                                  Kestofol PH/LV-R
# 112        КЕСТО       NaN                               Kesto Electric Plus
# 120        КЕСТО       NaN                                    Kestomer VPC-R
# 121        КЕСТО       NaN                                     Kestomer VТ-R
# 122        КЕСТО       NaN                                   Sitol 2062/UV-R
# 130        КЕСТО       NaN                               Kesto Electric Tape
# 131        КЕСТО       NaN                             Kesto Electric Primer
# 134        КЕСТО       NaN                                        Hardener C
# 138        КЕСТО       NaN                                      Sitol 2394-R
# 139        КЕСТО       NaN                                      Sitol 2395-R
# 140        КЕСТО       NaN                                      Sitol 2396-R
# 141        КЕСТО       NaN                                      Sitol 2397-R
# 142        КЕСТО       NaN                                  Kestomer VPE/А-R
# 143        КЕСТО       NaN                                    Sitol 2062/L-R
# 151        КЕСТО       NaN                         Kesto Шпатель зубчатый A2
# 152        КЕСТО       NaN                        Kesto Шпатель зубчатый B10
# 160        КЕСТО       NaN                                      Sitol 7010-R
# 173  КРИО_СЕРВИС       NaN                  Ацетилен растворённый в баллонах
# 174  КРИО_СЕРВИС       NaN                 Пропан-бутановая смесь в баллонах
# 175  КРИО_СЕРВИС       NaN                   Кислород технический в баллонах
# 176  КРИО_СЕРВИС       NaN       Углекислота (двуоксись углерода) в баллонах
# 177  КРИО_СЕРВИС       NaN            Смесь сварочная ArCO2 80/20 в баллонах
# 178  КРИО_СЕРВИС       NaN                              Аргон в/ч в баллонах
# 179  КРИО_СЕРВИС       NaN                               Азот в/ч в баллонах
# 180  КРИО_СЕРВИС       NaN                           Гелий (м.Б.) в баллонах
# 181  КРИО_СЕРВИС       NaN           Ацетилен растворённый в баллонах Unitor
# 182  КРИО_СЕРВИС       NaN            Кислород технический в баллонах Unitor
# 183  КРИО_СЕРВИС       NaN                        Азот в/ч в баллонах Unitor
# 184  КРИО_СЕРВИС       NaN                    Пищевую смесь N2CO2 в баллонах
# 185  КРИО_СЕРВИС       NaN                       Ацетилен марки А в баллонах
# 186  КРИО_СЕРВИС       NaN                  Ацетилен растворённый в баллонах
# 187  КРИО_СЕРВИС       NaN                                  Аргон в баллонах
# 188  КРИО_СЕРВИС       NaN                   Кислород технический в баллонах
# 189  КРИО_СЕРВИС       NaN                                   Азот в баллонах
# 190  КРИО_СЕРВИС       NaN        Углекислота (двуокись углерода) в баллонах
# 191  КРИО_СЕРВИС       NaN                               Баллон ацетиленовый
# 192  КРИО_СЕРВИС       NaN                 Баллон ацетиленовый малой ёмкости
# 193  КРИО_СЕРВИС       NaN                                   Баллон гелиевый
# 194  КРИО_СЕРВИС       NaN                     Баллон гелиевый малой ёмкости
# 195  КРИО_СЕРВИС       NaN                                Баллон кислородный
# 196  КРИО_СЕРВИС       NaN                  Баллон кислородный малой ёмкости
# 197  КРИО_СЕРВИС       NaN                              Баллон углекислотный
# 198  КРИО_СЕРВИС       NaN                Баллон углекислотный малой ёмкости
# 199  КРИО_СЕРВИС       NaN                Баллон аргоновый / сварочная смесь
# 200  КРИО_СЕРВИС       NaN  Баллон аргоновый малой ёмкости / сварочная смесь
# 201  КРИО_СЕРВИС       NaN                                    Баллон азотный
# 202  КРИО_СЕРВИС       NaN                         Баллон пропановый «новый»
#
#         Цена  Скидочная Цена  Объем Единицы Измерения
# 78     890.0           820.0    5.0                кг
# 94    3500.0          3250.0    1.0              литр
# 106  15200.0         14200.0   15.0                кг
# 112   4200.0          3950.0   18.0                кг
# 120   1650.0          1520.0   15.0                кг
# 121   1750.0          1620.0   15.0                кг
# 122   1950.0          1800.0   15.0                кг
# 130   2800.0          2600.0    0.5                кг
# 131   3200.0          3000.0    1.0              литр
# 134   2800.0          2600.0    1.0              литр
# 138   1850.0          1720.0   15.0                кг
# 139   1950.0          1800.0   15.0                кг
# 140   2050.0          1900.0   15.0                кг
# 141   2150.0          2000.0   15.0                кг
# 142   1850.0          1720.0   15.0                кг
# 143   1750.0          1620.0   15.0                кг
# 151    450.0           420.0    0.3                кг
# 152    550.0           500.0    0.4                кг
# 160   1850.0          1720.0   15.0                кг
# 173   4500.0             NaN   40.0              литр
# 174   1700.0             NaN   50.0              литр
# 175   1000.0             NaN   40.0              литр
# 176   1500.0             NaN   40.0              литр
# 177   2300.0             NaN   40.0              литр
# 178   2300.0             NaN   40.0              литр
# 179   1200.0             NaN   40.0              литр
# 180  30000.0             NaN   40.0              литр
# 181   5500.0             NaN   40.0              литр
# 182   2600.0             NaN   40.0              литр
# 183   3000.0             NaN   40.0              литр
# 184   3000.0             NaN   40.0              литр
# 185  30000.0             NaN   40.0              литр
# 186   3500.0             NaN   40.0              литр
# 187   1500.0             NaN   10.0              литр
# 188    500.0             NaN   40.0              литр
# 189   1000.0             NaN   40.0              литр
# 190   1000.0             NaN   17.0              литр
# 191   5900.0             NaN   40.0              литр
# 192   9900.0             NaN   10.0              литр
# 193  12000.0             NaN   40.0              литр
# 194   6500.0             NaN   10.0              литр
# 195   9800.0             NaN   40.0              литр
# 196   4600.0             NaN   12.0              литр
# 197   9800.0             NaN   40.0              литр
# 198   5500.0             NaN   30.0              литр
# 199   9800.0             NaN   40.0              литр
# 200   5500.0             NaN   10.0              литр
# 201   9800.0             NaN   40.0              литр
# 202   5500.0             NaN   50.0              литр

# %%
# Правильная группировка - используем существующие категории
additional_mapping = {
    # КЕСТО - Клеи и строительные смеси
    'Kesto Master Flis': 'Клеи и строительные смеси',
    'Отвердитель Hardener M': 'Клеи и строительные смеси',
    'Kestofol PH/LV-R': 'Клеи и строительные смеси', 
    'Kesto Electric Plus': 'Клеи и строительные смеси',
    'Kestomer VPC-R': 'Клеи и строительные смеси',
    'Kestomer VТ-R': 'Клеи и строительные смеси',
    'Sitol 2062/UV-R': 'Клеи и строительные смеси',
    'Kesto Electric Tape': 'Клеи и строительные смеси',
    'Kesto Electric Primer': 'Клеи и строительные смеси',
    'Hardener C': 'Клеи и строительные смеси',
    'Sitol 2394-R': 'Клеи и строительные смеси',
    'Sitol 2395-R': 'Клеи и строительные смеси',
    'Sitol 2396-R': 'Клеи и строительные смеси',
    'Sitol 2397-R': 'Клеи и строительные смеси',
    'Kestomer VPE/А-R': 'Клеи и строительные смеси',
    'Sitol 2062/L-R': 'Клеи и строительные смеси',
    'Sitol 7010-R': 'Клеи и строительные смеси',
    'Kesto Шпатель зубчатый A2': 'Клеи и строительные смеси',
    'Kesto Шпатель зубчатый B10': 'Клеи и строительные смеси',
    
    # КРИО_СЕРВИС - Газы в баллонах 
    'Ацетилен растворённый в баллонах': 'Газы и газовые смеси',
    'Пропан-бутановая смесь в баллонах': 'Газы и газовые смеси',
    'Кислород технический в баллонах': 'Газы и газовые смеси',
    'Углекислота (двуоксись углерода) в баллонах': 'Газы и газовые смеси',
    'Смесь сварочная ArCO2 80/20 в баллонах': 'Газы и газовые смеси',
    'Аргон в/ч в баллонах': 'Газы и газовые смеси',
    'Азот в/ч в баллонах': 'Газы и газовые смеси',
    'Гелий (м.Б.) в баллонах': 'Газы и газовые смеси',
    'Ацетилен растворённый в баллонах Unitor': 'Газы и газовые смеси',
    'Кислород технический в баллонах Unitor': 'Газы и газовые смеси',
    'Азот в/ч в баллонах Unitor': 'Газы и газовые смеси',
    'Пищевую смесь N2CO2 в баллонах': 'Газы и газовые смеси',
    'Ацетилен марки А в баллонах': 'Газы и газовые смеси',
    'Аргон в баллонах': 'Газы и газовые смеси', 
    'Азот в баллонах': 'Газы и газовые смеси',
    'Углекислота (двуокись углерода) в баллонах': 'Газы и газовые смеси',
    
    # КРИО_СЕРВИС - Баллоны 
    'Баллон ацетиленовый': 'Сварочные материалы и оборудование',
    'Баллон ацетиленовый малой ёмкости': 'Сварочные материалы и оборудование',
    'Баллон гелиевый': 'Сварочные материалы и оборудование',
    'Баллон гелиевый малой ёмкости': 'Сварочные материалы и оборудование',
    'Баллон кислородный': 'Сварочные материалы и оборудование',
    'Баллон кислородный малой ёмкости': 'Сварочные материалы и оборудование',
    'Баллон углекислотный': 'Сварочные материалы и оборудование',
    'Баллон углекислотный малой ёмкости': 'Сварочные материалы и оборудование',
    'Баллон аргоновый / сварочная смесь': 'Сварочные материалы и оборудование',
    'Баллон аргоновый малой ёмкости / сварочная смесь': 'Сварочные материалы и оборудование',
    'Баллон азотный': 'Сварочные материалы и оборудование',
    'Баллон пропановый «новый»': 'Сварочные материалы и оборудование'
}

def data_category_fillna(row):
    name = row['Название товара']
    return additional_mapping[name]
data.loc[data['Категория'].isna(), 'Категория'] = data.loc[data['Категория'].isna()].apply(data_category_fillna, axis = 1)

# %%
data['Категория'].unique()
# Out:
# array(['Газы и газовые смеси', 'Промышленные технологии', 'Косметика',
#        'Герметики', 'Клеи и строительные смеси',
#        'Сварочные материалы и оборудование'], dtype=object)

# %%
data.isna().mean()
# Out:
# Компания             0.00000
# Категория            0.00000
# Название товара      0.00000
# Цена                 0.00000
# Скидочная Цена       0.63551
# Объем                0.00000
# Единицы Измерения    0.00000
# dtype: float64

# %%
data_no_discount = data.drop(columns = ['Скидочная Цена'])

# %%
data = data.drop_duplicates()

# %%
data.isna().mean()
# Out:
# Компания             0.000000
# Категория            0.000000
# Название товара      0.000000
# Цена                 0.000000
# Скидочная Цена       0.616691
# Объем                0.000000
# Единицы Измерения    0.000000
# dtype: float64

# %%
for item in data['Название товара'].items():
    print(item)
# Out:
# (0, 'КИСЛОРОД газообразный технический ГОСТ 5583-78, 1сорт')
# (1, 'Кислород газообразный медицинский ФСП ЛП-001553')
# (2, 'Кислород особой чистоты 99,99%')
# (3, 'Азот / Двуокись углерода')
# (4, 'Кислород жидкий технический ГОСТ 6331-78')
# (5, 'Кислород жидкий медицинский ФСП ЛП-001553')
# (6, 'Двуокись углерода ГОСТ 8050-85, высший сорт')
# (7, 'Жидкий азот')
# (8, 'Азот газообразный особой чистоты (99,999%)')
# (9, 'Азот газообразный технический ГОСТ 9293-74')
# (10, 'Аргон газообразный особо чистый (99,999%)')
# (11, 'Азот жидкий технический ГОСТ 9293-74')
# (12, 'Пропан-бутановая смесь')
# (13, 'Аргон газообразный ГОСТ 10157-2016, высший сорт (>99,993%)')
# (14, 'Аргон жидкий ГОСТ 10157-2016')
# (15, 'Ацетилен марки Б')
# (16, 'Гелий марки А (99,995%) ТУ 0271-135-31323949-2005')
# (17, 'Гелий марки Б (99,99%) ТУ 0271-135-31323949-2005')
# (18, 'Газовые смеси сварочные')
# (19, 'Сухой лед')
# (20, 'Kesto Masa Pro')
# (21, 'AKVAPUR SM 3000')
# (22, 'Kestopur 1C 10H')
# (23, 'Sitol 2189-R')
# (24, 'Sitol 5012/43')
# (25, 'Sitol 2085-R')
# (26, 'Sitol 1100 R')
# (27, 'Sitol 2390-R')
# (28, 'Sitol 2185-R')
# (29, 'Sitol 7000-R')
# (30, 'Kestomer VPH-R')
# (31, 'Kestomer VPV/S-R')
# (32, 'Sitol 4173-R')
# (33, 'Sitol 4181')
# (34, 'Sitol 4173/HV-R')
# (35, 'Sitol-4170-R')
# (36, 'Kestomer VPV-R')
# (37, 'Kesto Seal')
# (38, 'Kestopur 200/S')
# (39, 'Kesto Masa')
# (40, 'Kestopur 600/3')
# (41, 'Kestopur 600/15')
# (42, 'Kestopur 600/6')
# (43, 'Kesto 2 Plus')
# (44, 'Kesto LVT Plus')
# (45, 'Kesto Plus')
# (46, 'Kesto LH')
# (47, 'Kesto Eco Block')
# (48, 'Kesto PVA D3')
# (49, 'Kesto PVA Profi')
# (50, 'Kesto Saumalaasti')
# (51, 'Kesto Multi Floor')
# (52, 'Kesto Fiberpool')
# (53, 'Kesto Opti Floor')
# (54, 'Kesto Keragum')
# (55, 'Kesto Master Deco')
# (56, 'Kesto Fiberlast')
# (57, 'Kesto Fiberpool Primer')
# (58, 'Kesto Fix')
# (59, 'Kesto Pro Fix')
# (60, 'Kesto PVA D4')
# (61, 'Kesto Eco 2 K-PU')
# (62, 'Kesto EcoStandard')
# (63, 'Kesto Silicone')
# (64, 'Kesto ACRYL PRO')
# (65, 'Kesto ACRYL')
# (66, 'Kestopur 400/4')
# (67, 'Kestopur 400/2')
# (68, 'Kestopur PL240')
# (69, 'Kestopur 200/90')
# (70, 'Kestopur 15-15')
# (71, 'Kestopur 200/50')
# (72, 'Kestopur 200/30')
# (73, 'Kestokol DS-R')
# (74, 'Kestokol DS/HV-R')
# (75, 'Kestokol DM-R')
# (76, 'Kesto Kestokol D4000 (PVA D4)')
# (77, 'Kestokol D300 (PVA D3)')
# (78, 'Kesto Master Flis')
# (79, 'Kesto Clean')
# (80, 'AKVAPUR SM 1000')
# (81, 'Kesto Premium Fix')
# (82, 'Kestokol D301')
# (83, 'Kestokol D3')
# (84, 'Kestofol PHL-R')
# (85, 'KESTOMELT S200')
# (86, 'Kestokol DM/HV-R')
# (87, 'Sitol 2340/В-R')
# (88, 'Kesto ULTRA FIX')
# (89, 'Kesto Master Pro')
# (90, 'Kesto 2 K-PU')
# (91, 'Kesto Eco 2K-PU Green')
# (92, 'Kesto Flex Silan')
# (93, 'Kesto Primer')
# (94, 'Отвердитель Hardener M')
# (95, 'Kestomer VPG-R')
# (96, 'Kestomer VP-R')
# (97, 'Sitol 4170/S-R')
# (98, 'Sitol 4180-R')
# (99, 'Kestomer VPS-R')
# (100, 'Kestofol PH/P-R')
# (101, 'Kestofol PH-R')
# (102, 'Kesto Light Primer')
# (103, 'Kestokol PVA Profi-R')
# (104, 'Kesto Carpet Fix')
# (105, 'Kesto Keraband')
# (106, 'Kestofol PH/LV-R')
# (107, 'Kesto Extra Plus')
# (108, 'KESTOMELT K610')
# (109, 'KESTOMELT K608')
# (110, 'Kestokol 330')
# (111, 'Kestomer VP/LV-R')
# (112, 'Kesto Electric Plus')
# (113, 'Sitol 4176-R')
# (114, 'Sitol 4176/UV-R')
# (115, 'Sitol 4171-R')
# (116, 'Kestokol D300 HV')
# (117, 'Kestokol M05')
# (118, 'Kestokol WR125')
# (119, 'Kestomer VPE/UV-R')
# (120, 'Kestomer VPC-R')
# (121, 'Kestomer VТ-R')
# (122, 'Sitol 2062/UV-R')
# (123, 'Sitol 4175-R')
# (124, 'Sitol 4171/1-R')
# (125, 'Sitol 4176/T-R')
# (126, 'Sitol 4310')
# (127, 'Sitol 4401')
# (128, 'Sitol 3348-R')
# (129, 'Kestokol WR6040')
# (130, 'Kesto Electric Tape')
# (131, 'Kesto Electric Primer')
# (132, 'Kesto TR')
# (133, 'Kesto Opti Gyps Light')
# (134, 'Hardener C')
# (135, 'Sitol 2072-R')
# (136, 'Sitol 2063-R')
# (137, 'Sitol 2186-R')
# (138, 'Sitol 2394-R')
# (139, 'Sitol 2395-R')
# (140, 'Sitol 2396-R')
# (141, 'Sitol 2397-R')
# (142, 'Kestomer VPE/А-R')
# (143, 'Sitol 2062/L-R')
# (144, 'Sitol 8060-R')
# (145, 'Sitol 8082/UV-R')
# (146, 'Sitol 8085-R')
# (147, 'Sitol 8085/UV-R')
# (148, 'Sitol 8185-R')
# (149, 'Sitol 8189-R')
# (150, 'Sitol 8303-R')
# (151, 'Kesto Шпатель зубчатый A2')
# (152, 'Kesto Шпатель зубчатый B10')
# (153, 'Sitol 2303-R')
# (154, 'Sitol 2062-R')
# (155, 'Sitol 4171-СR')
# (156, 'Kestomer VPN/HV-R')
# (157, 'Sitol 4171/TR')
# (158, 'Kestomer VPN-R')
# (159, 'Sitol 2060-R')
# (160, 'Sitol 7010-R')
# (161, 'Sitol 4170/HV-R')
# (162, 'Sitol 3900-R')
# (163, 'Kestomer VPE-R')
# (164, 'Sitol 4815-R')
# (165, 'Sitol 4172-R')
# (166, 'Sitol 4180/S-R')
# (167, 'Sitol 4171/M-R')
# (168, 'Sitol 4171/LV-R')
# (169, 'Kesto Finish')
# (170, 'Kesto Eco Block Winter')
# (171, 'Kesto TF')
# (172, 'Kesto TT')
# (173, 'Ацетилен растворённый в баллонах')
# (174, 'Пропан-бутановая смесь в баллонах')
# (175, 'Кислород технический в баллонах')
# (176, 'Углекислота (двуоксись углерода) в баллонах')
# (177, 'Смесь сварочная ArCO2 80/20 в баллонах')
# (178, 'Аргон в/ч в баллонах')
# (179, 'Азот в/ч в баллонах')
# (180, 'Гелий (м.Б.) в баллонах')
# (181, 'Ацетилен растворённый в баллонах Unitor')
# (182, 'Кислород технический в баллонах Unitor')
# (183, 'Азот в/ч в баллонах Unitor')
# (184, 'Пищевую смесь N2CO2 в баллонах')
# (185, 'Ацетилен марки А в баллонах')
# (186, 'Ацетилен растворённый в баллонах')
# (187, 'Аргон в баллонах')
# (188, 'Кислород технический в баллонах')
# (189, 'Азот в баллонах')
# (190, 'Углекислота (двуокись углерода) в баллонах')
# (191, 'Баллон ацетиленовый')
# (192, 'Баллон ацетиленовый малой ёмкости')
# (193, 'Баллон гелиевый')
# (194, 'Баллон гелиевый малой ёмкости')
# (195, 'Баллон кислородный')
# (196, 'Баллон кислородный малой ёмкости')
# (197, 'Баллон углекислотный')
# (198, 'Баллон углекислотный малой ёмкости')
# (199, 'Баллон аргоновый / сварочная смесь')
# (200, 'Баллон аргоновый малой ёмкости / сварочная смесь')
# (201, 'Баллон азотный')
# (202, 'Баллон пропановый «новый»')
# (203, 'Масло-концентрат для интенсивного омоложения с эфирным маслом розы')
# (204, 'Гель для умывания на основе гидролата розы для эффективного очищения, 200 мл')
# (205, 'Восстанавливающий крем на основе гидролата розы для комплексного омоложения')
# (206, 'Гидролат розы для сохранения красоты, 200 мл')
# (207, 'Масло-концентрат для лица с маслом розы, 15 мл')
# (208, 'Увлажняющий крем на основе гидролата розы для нормальной и комбинированной кожи')
# (209, 'Ультрапитательный крем на основе гидролата розы для сухой и очень сухой кожи')
# (210, 'Маска глубокоочищающая с экстрактом грязи Сакского озера 1 шт., 25 мл')
# (211, 'Маска глубокоочищающая с экстрактом грязи Сакского озера 10 шт. по 25 мл')
# (212, 'Бальзам для губ питательный')
# (213, 'Крем для век омолаживающий с экстрактом лаванды')
# (214, 'Крем для век увлажняющий с экстрактом лаванды')
# (215, 'Бальзам для губ увлажняющий')
# (216, 'Тканевая маска-бустер увлажняющая с лавандой и розой')
# (217, 'Тканевая детокс-маска  на основе гидролата розы')
# (218, 'Тканевая маска-филлер омолаживающая с лавандой и розой')
# (219, 'Тканевая лифтинг-маска на основе гидролата розы')
# (220, 'Тканевая маска-бустер питательная  на основе гидролата розы')
# (221, 'Тканевая маска-бустер обновляющая с лавандой и розой')
# (222, 'Матирующий крем на основе гидролата розы от несовершенств кожи')
# (223, 'Лифтинг-сыворотка на основе гидролата розы для комплексного омоложения')
# (224, 'Лифтинг-маска на основе гидролата розы для комплексного омоложения')
# (225, 'Антиоксидантный крем на основе гидролата розы для борьбы с последствиями стресса')
# (226, 'Питательный крем на основе гидролата розы для нормальной и склонной к сухости кожи')
# (227, 'Регенерирующий крем на основе гидролата розы для реактивной кожи')
# (228, 'Обновляющий тоник на основе гидролата розы для сияния кожи, 200 мл')
# (229, 'Успокаивающая сыворотка на основе гидролата розы для восстановления повреждений кожи')
# (230, 'Отбеливающий крем на основе гидролата розы для ровного цвета лица')
# (231, 'Увлажняющий тонер на основе гидролата розы для восстановления pH кожи, 100 мл')
# (232, 'Кремовый эксфолиант на основе гидролата розы для гладкости кожи')
# (233, 'Мицеллярная вода на основе гидролата розы для быстрого очищения без воды, 200 мл')
# (234, 'Увлажняющий тонер на основе гидролата розы для восстановления pH кожи, 200 мл')
# (235, 'Крем для век против темных кругов на основе гидролата розы')
# (236, 'Увлажняющая маска на основе гидролата розы для интенсивного восстановления, 50 мл')
# (237, 'Увлажняющая маска на основе гидролата розы для интенсивного восстановления')
# (238, 'Гиалуроновый концентрат на основе гидролата розы для глубокого увлажнения')
# (239, 'Лифтинг-маска на основе гидролата розы для комплексного омоложения, 50 мл')
# (240, 'Крем для век интенсивный на основе гидролата розы для комплексного омоложения')
# (241, 'Детокс-сыворотка на основе гидролата розы для борьбы с последствиями стресса')
# (242, 'Пенка для умывания на основе гидролата розы для деликатного очищения')
# (243, 'Обновляющий тоник на основе гидролата розы для сияния кожи, 100 мл')
# (244, 'Средство для интенсивного восстановления на основе гидролата розы для борьбы с последствиями стресса')
# (245, 'Отбеливающий тоник на основе гидролата розы для ровного цвета лица')
# (246, 'AHA-пилинг на основе гидролата розы для сияния кожи')
# (247, 'Матирующий мист на основе гидролата розы от несовершенств кожи')
# (248, 'Жидкие патчи под глаза на основе гидролата розы против отеков')
# (249, 'Молочко для снятия макияжа на основе гидролата розы для мягкого очищения без воды, 200мл')
# (250, 'Мицеллярная вода на основе гидролата розы для быстрого очищения без воды, 100 мл')
# (251, 'Гоммаж на основе гидролата розы для обновления кожи')
# (252, 'Гидролат розы для сохранения красоты, 100 мл')
# (253, 'Гель для умывания на основе гидролата розы для эффективного очищения, 100 мл')
# (254, 'Гель для умывания на основе гидролата розы, 30 мл')
# (255, 'Обновляющий тоник на основе гидролата розы, 30 мл')
# (256, 'Тоник для лица увлажняющий с экстрактом лаванды, 30 мл')
# (257, 'Мицеллярная вода для лица освежающая с экстрактом лаванды, 30 мл')
# (258, 'Крем дневной с экстрактом грязи Сакского озера')
# (259, 'Гидролат розы  с экстрактом грязи Сакского озера, 200 мл')
# (260, 'Эксфолиант выравнивающий с экстрактом грязи Сакского озера')
# (261, 'Крем восстанавливающий с экстрактом грязи Сакского озера')
# (262, 'Гидролат розы  с экстрактом грязи Сакского озера, 100 мл')
# (263, 'Маска глубокоочищающая с грязью Сакского озера')
# (264, 'Маска успокаивающая с экстрактом грязи Сакского озера')
# (265, 'Маска-пилинг восстанавливающая с экстрактом грязи Сакского озера')
# (266, 'Пенка для умывания. Деликатная. Очищение кожи.')
# (267, 'Тоник восстанавливающий  с экстрактом грязи Сакского озера, 100 мл')
# (268, 'Крем-корректор интенсивный с экстрактом грязи Сакского озера для локального нанесения')
# (269, 'Тоник успокаивающий с экстрактом грязи Сакского озера, 200 мл')
# (270, 'Тоник восстанавливающий  с экстрактом грязи Сакского озера, 200 мл')
# (271, 'Бальзам ночной с экстрактом грязи Сакского озера')
# (272, 'Тоник успокаивающий с экстрактом грязи Сакского озера, 100 мл')
# (273, 'Тоник для лица увлажняющий с экстрактом лаванды, 200 мл')
# (274, 'Тоник для лица увлажняющий с экстрактом лаванды, 100 мл')
# (275, 'Тоник для лица балансирующий с экстрактом лаванды, 200 мл')
# (276, 'Тоник для лица балансирующий с экстрактом лаванды, 100 мл')
# (277, 'Сыворотка омолаживающая для лица с экстрактом лаванды')
# (278, 'Сыворотка балансирующая для лица с экстрактом лаванды')
# (279, 'Мицеллярная вода для лица освежающая с экстрактом лаванды, 200 мл')
# (280, 'Мицеллярная вода для лица освежающая с экстрактом лаванды, 100 мл')
# (281, 'Масло питательное для лица с лавандой и розой')
# (282, 'Маска для лица увлажняющая с экстрактом лаванды')
# (283, 'Эксфолиант для лица очищающий с экстрактом лаванды')
# (284, 'Крем-мусс для лица увлажняющий с экстрактом лаванды')
# (285, 'Крем для лица регенерирующий с экстрактом лаванды')
# (286, 'Крем для лица антивозрастной с экстрактом лаванды')
# (287, 'Гидролат лаванды и розы, 200 мл')
# (288, 'Гидролат лаванды и розы, 100 мл')
# (289, 'Гель для умывания очищающий с экстрактом лаванды, 200 мл')
# (290, 'Гель для умывания очищающий с экстрактом лаванды, 100 мл')
# (291, 'Крем-масло для тела питательное с гидролатом розы, 150 мл')
# (292, 'Крем для рук увлажняющий, 30 мл')
# (293, 'Крем для рук увлажняющий, 75 мл')
# (294, 'Крем-масло для тела питательное, 250 мл')
# (295, 'Скраб для тела обновляющий, 250 мл')
# (296, 'Крем для тела ультраувлажняющий, 200 мл')
# (297, 'Скраб для ног смягчающий, 100 мл')
# (298, 'Молочко для тела укрепляющее, 200 мл')
# (299, 'Крем для рук восстанавливающий, 30мл')
# (300, 'Крем для рук и ногтей питательный с лавандой и розой')
# (301, 'Крем для ног обновляющий с лавандой и розой')
# (302, 'Спрей для тела ультраувлажняющий с лавандой и розой')
# (303, 'Гель для душа очищающий с лавандой и розой')
# (304, 'Масло-концентрат для тела омолаживающее с лавандой и розой')
# (305, 'Крем-гель для душа увлажняющий с лавандой и розой')
# (306, 'Гель для интимной гигиены освежающий с лавандой и розой')
# (307, 'Крем-щербет для тела увлажняющий с лавандой и розой')
# (308, 'Скраб для тела мультиабразивный с лавандой и розой')
# (309, 'Крем для тела омолаживающий с лавандой и розой')
# (310, 'Скраб для тела кофейный с лавандой и розой')
# (311, 'Крем-баттер для тела питательный с лавандой и розой')
# (312, 'Мусс-скраб для тела солевой с лавандой и розой')
# (313, 'Крем для тела ультраувлажняющий, 30 мл')
# (314, 'Крем-гель для душа увлажняющий, 30 мл')
# (315, 'Крем для рук восстанавливающий, 75 мл')
# (316, 'Гоммаж для тела эксфолиирующий, 200 мл')
# (317, 'Гель для ног охлаждающий, 75 мл')
# (318, 'Мусс для интимной гигиены освежающий, 150 мл')
# (319, 'Гель-скраб для душа очищающий, 250 мл')
# (320, 'Крем-гель для душа увлажняющий, 250 мл')
# (321, 'Спрей-концентрат для волос с гидролатом розы')
# (322, 'Молочко для волос Многофункциональное')
# (323, 'Шампунь Укрепляющий')
# (324, 'Сыворотка для волос Балансирующая')
# (325, 'Маска для волос Восстанавливающая')
# (326, 'Сыворотка для волос Укрепляющая')
# (327, 'Бальзам-маска для волос Питательная')
# (328, 'Бальзам для волос Увлажняющий')
# (329, 'Шампунь увлажняющий, 30 мл')
# (330, 'Бальзам для волос увлажняющий, 30 мл')
# (331, 'Шампунь Балансирующий')
# (332, 'Шампунь для волос против перхоти')
# (333, 'Шампунь Питательный')
# (334, 'Шампунь Увлажняющий')
# (335, 'Укрепляющий комплекс для ухода за волосами и кожей головы')
# (336, 'Комплексное решение для ухода за кожей тела и рук "Максимальное Увлажнение"')
# (337, 'Балансирующий комплекс для ухода за волосами и кожей головы')
# (338, 'Комплексное решение для ухода за кожей тела и рук "Интенсивное Питание"')
# (339, 'Увлажняющий комплекс для ухода за волосами')
# (340, 'Питательный комплекс для ухода за волосами')
# (341, 'Комплексное решение "Базовый уход для мужчин"')
# (342, 'Комплексное решение "Комфортное бритье и увлажнение для мужчин"')
# (343, 'Cкажи нет раздражениям')
# (344, 'UnStress')
# (345, 'Комплексное решение для ухода за телом "Глубокое увлажнение кожи с лавандой и розой"')
# (346, 'Комплексное решение для ухода за телом "Интенсивное омоложение кожи с лавандой и розой"')
# (347, 'Комплексное решение "Глубокое очищение для проблемной и жирной кожи"')
# (348, 'Комплексное решение "Базовый уход за проблемной и жирной кожей"')
# (349, 'Комплексное решение "Против воспалений для проблемной и жирной кожи"')
# (350, 'Комплексное решение "Коррекция постакне"')
# (351, 'Комплексное омоложение')
# (352, 'Комплексное решение для лица “Супер Увлажнение”')
# (353, 'Ровный тон')
# (354, 'Контроль блеска')
# (355, 'Набор «Чистота и здоровье кожи»')
# (356, 'Набор «Молодость и сияние»')
# (357, 'Набор «Питание и обновление»')
# (358, 'Набор «Интенсивное увлажнение»')
# (359, 'Подарочный набор «Lava Sub Rosa»')
# (360, 'Подарочный набор «Rosa Аb Origine»')
# (361, 'Подарочный набор Uomo Sub Rosa "Свобода быть собой"')
# (362, 'Брендированная коробка UOMO SUB ROSA')
# (363, 'Брендированная коробка "Крымская Роза"')
# (364, 'Набор косметики "Знакомство с брендом"')
# (365, 'Гель для душа освежающий  с экстрактом шиповника, 30 мл')
# (366, 'Шампунь-кондиционер увлажняющий с экстрактом шиповника, 30 мл')
# (367, 'Шампунь-кондиционер увлажняющий с экстрактом шиповника')
# (368, 'Крем для рук увлажняющий  с экстрактом шиповника')
# (369, 'Крем для лица увлажняющий с экстрактом шиповника')
# (370, 'Крем для лица антивозрастной с экстрактом шиповника')
# (371, 'Гель для душа освежающий  с экстрактом шиповника')
# (372, 'Гель для бритья охлаждающий с экстрактом шиповника')
# (373, 'Лосьон после бритья успокаивающий с экстрактом шиповника')
# (374, 'Эфирное масло грейпфрута')
# (375, 'Эфирное масло мяты')
# (376, 'Эфирное масло лимона')
# (377, 'Эфирное масло лаванды')
# (378, 'Эфирное масло розмарина')
# (379, 'Эфирное масло герани')
# (380, 'Эфирное масло полыни таврической')
# (381, 'Эфирное масло кипариса')
# (382, 'Эфирное масло чайного дерева')
# (383, 'Эфирное масло апельсина')
# (384, 'Эфирное масло иланг-иланга')
# (385, 'Эфирное масло розы')
# (386, 'Эфирное масло шалфея')
# (387, 'Эфирное масло мелиссы')
# (388, 'Лифтинг-маска на основе гидролата розы для комплексного омоложения')
# (389, 'Успокаивающая сыворотка на основе гидролата розы для восстановления повреждений кожи')
# (390, 'Детокс-сыворотка на основе гидролата розы для борьбы с последствиями стресса')
# (391, 'Средство для интенсивного восстановления на основе гидролата розы для борьбы с последствиями стресса')
# (392, 'Сыворотка балансирующая для лица с экстрактом лаванды')
# (393, 'Маска для лица увлажняющая с экстрактом лаванды')
# (394, 'Азот в/ч (99.998%)')
# (395, 'Азот в/ч (99.998%)')
# (396, 'Азот в/ч (99.998%)')
# (397, 'Азот в/ч (99.998%)')
# (398, 'Азот в/ч (99.998%)')
# (399, 'Азот в/ч (99.998%)')
# (400, 'Азот в/ч (99.998%)')
# (401, 'Азот в/ч (99.998%)')
# (402, 'Азот в/ч (99.998%)')
# (403, 'Азот в/ч (99.998%)')
# (404, 'Азот в/ч (99.998%)')
# (405, 'Азот в/ч (99.998%)')
# (406, 'Азот в/ч (99.998%)')
# (407, 'Азот в/ч (99.998%)')
# (409, 'Азот Марка 5.0 ОСЧ (99.999%)')
# (410, 'Азот Марка 5.0 ОСЧ (99.999%)')
# (411, 'Азот Марка 5.0 ОСЧ (99.999%)')
# (412, 'Азот Марка 5.0 ОСЧ (99.999%)')
# (413, 'Азот Марка 5.0 ОСЧ (99.999%)')
# (414, 'Азот Марка 5.0 ОСЧ (99.999%)')
# (415, 'Азот Марка 5.0 ОСЧ (99.999%)')
# (424, 'Азот Марка 5.5 (99,9995%)')
# (425, 'Азот Марка 5.5 (99,9995%)')
# (426, 'Азот Марка 5.5 (99,9995%)')
# (427, 'Азот Марка 5.5 (99,9995%)')
# (428, 'Азот Марка 5.5 (99,9995%)')
# (429, 'Азот Марка 5.5 (99,9995%)')
# (430, 'Азот Марка 5.5 (99,9995%)')
# (439, 'Азот Марка 6.0 (99.9999%)')
# (440, 'Азот Марка 6.0 (99.9999%)')
# (441, 'Азот Марка 6.0 (99.9999%)')
# (442, 'Азот Марка 6.0 (99.9999%)')
# (443, 'Азот Марка 6.0 (99.9999%)')
# (444, 'Азот Марка 6.0 (99.9999%)')
# (445, 'Азот Марка 6.0 (99.9999%)')
# (454, 'Азот поверочный нулевой')
# (455, 'Азот поверочный нулевой')
# (456, 'Азот поверочный нулевой')
# (457, 'Азот поверочный нулевой')
# (458, 'Азот поверочный нулевой')
# (466, 'Аммиак безводный сжиженный марки А (99.9%)')
# (467, 'Аммиак безводный сжиженный марки А (99.9%)')
# (468, 'Аргон в/ч высокой чистоты')
# (469, 'Аргон в/ч высокой чистоты')
# (470, 'Аргон в/ч высокой чистоты')
# (471, 'Аргон в/ч высокой чистоты')
# (472, 'Аргон в/ч высокой чистоты')
# (473, 'Аргон в/ч высокой чистоты')
# (474, 'Аргон в/ч высокой чистоты')
# (475, 'Аргон в/ч высокой чистоты')
# (476, 'Аргон в/ч высокой чистоты')
# (477, 'Аргон в/ч высокой чистоты')
# (478, 'Аргон в/ч высокой чистоты')
# (479, 'Аргон в/ч высокой чистоты')
# (480, 'Аргон в/ч высокой чистоты')
# (481, 'Аргон в/ч высокой чистоты')
# (483, 'Аргон Марка 5.5 (99,9995%)')
# (484, 'Аргон Марка 5.5 (99,9995%)')
# (485, 'Аргон Марка 5.5 (99,9995%)')
# (486, 'Аргон Марка 5.5 (99,9995%)')
# (487, 'Аргон Марка 5.5 (99,9995%)')
# (488, 'Аргон Марка 5.5 (99,9995%)')
# (489, 'Аргон Марка 5.5 (99,9995%)')
# (498, 'Аргон Марка 6.0 (99,9999%)')
# (499, 'Аргон Марка 6.0 (99,9999%)')
# (500, 'Аргон Марка 6.0 (99,9999%)')
# (501, 'Аргон Марка 6.0 (99,9999%)')
# (502, 'Аргон Марка 6.0 (99,9999%)')
# (503, 'Аргон Марка 6.0 (99,9999%)')
# (504, 'Аргон Марка 6.0 (99,9999%)')
# (513, 'Аргон Марка 6.5')
# (514, 'Аргон Марка 6.5')
# (515, 'Аргон Марка 6.5')
# (516, 'Аргон Марка 6.5')
# (517, 'Аргон Марка 6.5')
# (518, 'Аргон Марка 7.0')
# (519, 'Аргон Марка 7.0')
# (520, 'Аргон Марка 7.0')
# (521, 'Аргон Марка 7.0')
# (522, 'Аргон Марка 7.0')
# (523, 'Ацетилен Марка Б сорт первый (99.1%) 40л')
# (524, 'Ацетилен Марка Б сорт первый (99.1%) 40л')
# (525, 'Ацетилен Марка Б сорт первый (99.1%) 40л')
# (526, 'Ацетилен Марка А (99.5%)')
# (527, 'Ацетилен Марка А (99.5%)')
# (528, 'Ацетилен Марка А (99.5%)')
# (529, 'Ацетилен Марка А (99.5%)')
# (530, 'Ацетилен Марка А (99.5%)')
# (531, 'Ацетилен Марка А (99.5%)')
# (532, 'Водород в/ч')
# (533, 'Водород в/ч')
# (534, 'Водород в/ч')
# (535, 'Водород в/ч')
# (536, 'Водород в/ч')
# (537, 'Водород в/ч')
# (538, 'Водород в/ч')
# (539, 'Водород в/ч')
# (540, 'Водород в/ч')
# (541, 'Водород ОСЧ')
# (542, 'Водород ОСЧ')
# (543, 'Водород ОСЧ')
# (544, 'Водород ОСЧ')
# (545, 'Водород ОСЧ')
# (546, 'Водород ОСЧ')
# (547, 'Водород ОСЧ')
# (548, 'Водород ОСЧ')
# (549, 'Водород ОСЧ')
# (550, 'Водород Марка 5.0 (99,999%)')
# (551, 'Водород Марка 5.0 (99,999%)')
# (552, 'Водород Марка 5.0 (99,999%)')
# (553, 'Водород Марка 5.0 (99,999%)')
# (554, 'Водород Марка 5.0 (99,999%)')
# (555, 'Водород Марка 5.0 (99,999%)')
# (556, 'Водород Марка 5.0 (99,999%)')
# (557, 'Водород Марка 5.0 (99,999%)')
# (558, 'Водород Марка 5.0 (99,999%)')
# (559, 'Водород Марка 6.0 (99,9999%)')
# (560, 'Водород Марка 6.0 (99,9999%)')
# (561, 'Водород Марка 6.0 (99,9999%)')
# (562, 'Водород Марка 6.0 (99,9999%)')
# (563, 'Водород Марка 6.0 (99,9999%)')
# (564, 'Водород Марка 6.0 (99,9999%)')
# (565, 'Водород Марка 6.0 (99,9999%)')
# (566, 'Водород Марка 6.0 (99,9999%)')
# (567, 'Водород Марка 6.0 (99,9999%)')
# (568, 'Водород Марка 7.0 (99,99999%)')
# (569, 'Водород Марка 7.0 (99,99999%)')
# (570, 'Водород Марка 7.0 (99,99999%)')
# (571, 'Водород Марка 7.0 (99,99999%)')
# (572, 'Водород Марка 7.0 (99,99999%)')
# (573, 'Водород Марка 7.0 (99,99999%)')
# (574, 'Водород Марка 7.0 (99,99999%)')
# (580, 'Воздух поверочный нулевой (ПНГ) марка А (синтетический, храмотографический)')
# (581, 'Воздух поверочный нулевой (ПНГ) марка А (синтетический, храмотографический)')
# (582, 'Воздух поверочный нулевой (ПНГ) марка А (синтетический, храмотографический)')
# (583, 'Воздух поверочный нулевой (ПНГ) марка А (синтетический, храмотографический)')
# (584, 'Воздух поверочный нулевой (ПНГ) марка А (синтетический, храмотографический)')
# (585, 'Воздух поверочный нулевой (ПНГ) марка А (синтетический, храмотографический)')
# (586, 'Воздух поверочный нулевой (ПНГ) марка А (синтетический, храмотографический)')
# (587, 'Воздух поверочный нулевой (ПНГ) марка А (синтетический, храмотографический)')
# (588, 'Воздух сжатый, кл. 0, ГОСТ 17433-80')
# (589, 'Воздух сжатый, кл. 0, ГОСТ 17433-80')
# (590, 'Воздух сжатый, кл. 0, ГОСТ 17433-80')
# (591, 'Воздух сжатый, кл. 0, ГОСТ 17433-80')
# (592, 'Воздух сжатый, кл. 0, ГОСТ 17433-80')
# (593, 'Воздух сжатый, кл. 0, ГОСТ 17433-80')
# (594, 'Воздух сжатый, кл. 0, ГОСТ 17433-80')
# (595, 'Воздух сжатый, кл. 0, ГОСТ 17433-80')
# (596, 'Воздух сжатый синтетический')
# (597, 'Воздух сжатый синтетический')
# (598, 'Воздух сжатый синтетический')
# (599, 'Воздух сжатый синтетический')
# (600, 'Воздух сжатый синтетический')
# (601, 'Воздух сжатый синтетический')
# (602, 'Воздух сжатый синтетический')
# (603, 'Воздух сжатый синтетический')
# (604, 'Гелий Марка Б 4.0 (99,99%)')
# (605, 'Гелий Марка Б 4.0 (99,99%)')
# (606, 'Гелий Марка Б 4.0 (99,99%)')
# (607, 'Гелий Марка Б 4.0 (99,99%)')
# (608, 'Гелий Марка Б 4.0 (99,99%)')
# (609, 'Гелий Марка Б 4.0 (99,99%)')
# (610, 'Гелий Марка Б 4.0 (99,99%)')
# (611, 'Гелий Марка Б 4.0 (99,99%)')
# (612, 'Гелий Марка Б 4.0 (99,99%)')
# (613, 'Гелий Марка Б 4.0 (99,99%)')
# (614, 'Гелий Марка Б 4.0 (99,99%)')
# (616, 'Гелий Марка А 4,5 (99,995%)')
# (617, 'Гелий Марка А 4,5 (99,995%)')
# (618, 'Гелий Марка А 4,5 (99,995%)')
# (619, 'Гелий Марка А 4,5 (99,995%)')
# (620, 'Гелий Марка А 4,5 (99,995%)')
# (621, 'Гелий Марка А 4,5 (99,995%)')
# (622, 'Гелий Марка А 4,5 (99,995%)')
# (623, 'Гелий Марка А 4,5 (99,995%)')
# (625, 'Гелий Марка 5,5 (99,9995%)')
# (626, 'Гелий Марка 5,5 (99,9995%)')
# (627, 'Гелий Марка 5,5 (99,9995%)')
# (628, 'Гелий Марка 5,5 (99,9995%)')
# (629, 'Гелий Марка 5,5 (99,9995%)')
# (630, 'Гелий Марка 5,5 (99,9995%)')
# (631, 'Гелий Марка 5,5 (99,9995%)')
# (632, 'Гелий Марка 5,5 (99,9995%)')
# (633, 'Гелий Марка 5,5 (99,9995%)')
# (634, 'Гелий Марка 5,5 (99,9995%)')
# (635, 'Гелий Марка 5,5 (99,9995%)')
# (637, 'Гелий Марка 6,0 (99,9999%)')
# (638, 'Гелий Марка 6,0 (99,9999%)')
# (639, 'Гелий Марка 6,0 (99,9999%)')
# (640, 'Гелий Марка 6,0 (99,9999%)')
# (641, 'Гелий Марка 6,0 (99,9999%)')
# (642, 'Гелий Марка 6,0 (99,9999%)')
# (643, 'Гелий Марка 6,0 (99,9999%)')
# (644, 'Гелий Марка 6,0 (99,9999%)')
# (645, 'Гелий Марка 6,0 (99,9999%)')
# (646, 'Гелий Марка 6,0 (99,9999%)')
# (647, 'Гелий Марка 6,0 (99,9999%)')
# (649, 'Гелий Марка 7.0 (99,99999%)')
# (650, 'Гелий Марка 7.0 (99,99999%)')
# (651, 'Гелий Марка 7.0 (99,99999%)')
# (652, 'Гелий Марка 7.0 (99,99999%)')
# (653, 'Гелий Марка 7.0 (99,99999%)')
# (654, 'Гелий Марка 7.0 (99,99999%)')
# (655, 'Гелий Марка 7.0 (99,99999%)')
# (656, 'Гелий Марка 7.0 (99,99999%)')
# (657, 'Гелий Марка 7.0 (99,99999%)')
# (658, 'Гелий Марка 7.0 (99,99999%)')
# (659, 'Гелий Марка 7.0 (99,99999%)')
# (661, 'Кислород технический (99,7%)')
# (662, 'Кислород технический (99,7%)')
# (663, 'Кислород технический (99,7%)')
# (664, 'Кислород технический (99,7%)')
# (665, 'Кислород технический (99,7%)')
# (666, 'Кислород технический (99,7%)')
# (667, 'Кислород технический (99,7%)')
# (668, 'Кислород технический (99,7%)')
# (669, 'Кислород технический (99,7%)')
# (670, 'Кислород технический (99,7%)')
# (671, 'Кислород технический (99,7%)')
# (673, 'Кислород 5.5 ОСЧ (99,9995%)')
# (674, 'Кислород 5.5 ОСЧ (99,9995%)')
# (675, 'Кислород 5.5 ОСЧ (99,9995%)')
# (676, 'Кислород 5.5 ОСЧ (99,9995%)')
# (677, 'Кислород 5.5 ОСЧ (99,9995%)')
# (678, 'Кислород 5.5 ОСЧ (99,9995%)')
# (679, 'Кислород 5.5 ОСЧ (99,9995%)')
# (680, 'Кислород 5.5 ОСЧ (99,9995%)')
# (681, 'Кислород 5.5 ОСЧ (99,9995%)')
# (682, 'Кислород 6.0 (99,9999%)')
# (683, 'Кислород 6.0 (99,9999%)')
# (684, 'Кислород 6.0 (99,9999%)')
# (685, 'Кислород 6.0 (99,9999%)')
# (686, 'Кислород 6.0 (99,9999%)')
# (687, 'Кислород 6.0 (99,9999%)')
# (688, 'Кислород 6.0 (99,9999%)')
# (689, 'Кислород 6.0 (99,9999%)')
# (690, 'Кислород 6.0 (99,9999%)')
# (691, 'Кислород 7.0 (99,99999%)')
# (692, 'Кислород 7.0 (99,99999%)')
# (693, 'Кислород 7.0 (99,99999%)')
# (694, 'Метан в/ч (99,8%)')
# (695, 'Метан в/ч (99,8%)')
# (696, 'Метан в/ч (99,8%)')
# (697, 'Метан в/ч (99,8%)')
# (698, 'Метан в/ч (99,8%)')
# (699, 'Метан в/ч (99,8%)')
# (700, 'Метан в/ч (99,8%)')
# (701, 'Метан в/ч (99,8%)')
# (702, 'Метан в/ч (99,8%)')
# (703, 'Метан в/ч (99,8%)')
# (704, 'Метан в/ч (99,8%)')
# (706, 'Метан Марка 4.5 (99,995%)')
# (707, 'Метан Марка 4.5 (99,995%)')
# (708, 'Метан Марка 4.5 (99,995%)')
# (709, 'Метан Марка 4.5 (99,995%)')
# (710, 'Метан Марка 4.5 (99,995%)')
# (711, 'Метан Марка 4.5 (99,995%)')
# (712, 'Метан Марка 4.5 (99,995%)')
# (713, 'Метан Марка 4.5 (99,995%)')
# (715, 'Метан Марка 5,5 (99,9995%)')
# (716, 'Метан Марка 5,5 (99,9995%)')
# (717, 'Метан Марка 5,5 (99,9995%)')
# (718, 'Метан Марка 5,5 (99,9995%)')
# (719, 'Метан Марка 5,5 (99,9995%)')
# (720, 'Метан Марка 5,5 (99,9995%)')
# (721, 'Метан Марка 5,5 (99,9995%)')
# (722, 'Метан Марка 5,5 (99,9995%)')
# (724, 'Пропан для автопогрузчиков')
# (725, 'Пропан для автопогрузчиков')
# (726, 'Пропан для автопогрузчиков')
# (727, 'Пропан для автопогрузчиков')
# (728, 'Пропан для автопогрузчиков')
# (729, 'Пропан для автопогрузчиков')
# (730, 'Пропан для автопогрузчиков')
# (731, 'Пропан для автопогрузчиков')
# (732, 'Пропан для автопогрузчиков')
# (733, 'Пропан для автопогрузчиков')
# (734, 'Пропан для автопогрузчиков')
# (735, 'Пропан для автопогрузчиков')
# (736, 'Пропан технический (СПБТ)')
# (737, 'Пропан технический (СПБТ)')
# (738, 'Пропан технический (СПБТ)')
# (739, 'Пропан технический (СПБТ)')
# (740, 'Пропан технический (СПБТ)')
# (741, 'Пропан технический (СПБТ)')
# (742, 'Пропан технический (СПБТ)')
# (743, 'Пропан технический (СПБТ)')
# (744, 'Пропан технический (СПБТ)')
# (745, 'Пропан технический (СПБТ)')
# (746, 'Пропан технический (СПБТ)')
# (747, 'Пропан технический (СПБТ)')
# (748, 'Пропан высокой чистоты, 1л')
# (749, 'Углекислота высший сорт (99,9%)')
# (750, 'Углекислота высший сорт (99,9%)')
# (751, 'Углекислота высший сорт (99,9%)')
# (752, 'Углекислота высший сорт (99,9%)')
# (753, 'Углекислота высший сорт (99,9%)')
# (754, 'Углекислота высший сорт (99,9%)')
# (755, 'Углекислота высший сорт (99,9%)')
# (756, 'Углекислота высший сорт (99,9%)')
# (757, 'Углекислота высший сорт (99,9%)')
# (758, 'Углекислота высший сорт (99,9%)')
# (759, 'Углекислота высший сорт (99,9%)')
# (760, 'Углекислота высший сорт (99,9%)')
# (761, 'Углекислота пищевая (99,9%)')
# (762, 'Углекислота пищевая (99,9%)')
# (763, 'Углекислота пищевая (99,9%)')
# (764, 'Углекислота пищевая (99,9%)')
# (765, 'Углекислота пищевая (99,9%)')
# (766, 'Углекислота пищевая (99,9%)')
# (767, 'Углекислота пищевая (99,9%)')
# (768, 'Углекислота пищевая (99,9%)')
# (769, 'Углекислота пищевая (99,9%)')
# (770, 'Углекислота пищевая (99,9%)')
# (771, 'Углекислота пищевая (99,9%)')
# (772, 'Углекислота пищевая (99,9%)')
# (773, 'Углекислота ОСЧ Марка 4,5 (99,995%)')
# (774, 'Углекислота ОСЧ Марка 5,3 (99,9993%)')
# (775, 'Элегаз SF-6 п/ч повышенной чистоты (99.997%). Производство Китай. Баллон 40 литров входит в стоимость.')
# (776, 'Элегаз SF-6 п/ч повышенной чистоты (99.997%). Производство Китай. Баллон 40 литров входит в стоимость.')
# (777, 'Кислород жидкий, заправка в сосуд Дьюара')
# (778, 'Кислород жидкий, заправка в сосуд Дьюара')
# (779, 'Кислород жидкий, заправка в криоцилиндр')
# (780, 'Кислород жидкий, заправка в газификатор')
# (781, 'Азот жидкий, заправка в сосуд Дьюара')
# (782, 'Азот жидкий, заправка в сосуд Дьюара')
# (783, 'Азот жидкий, заправка в криоцилиндр')
# (784, 'Азот жидкий, заправка в газификатор')
# (785, 'Смесь сварочная (He + Ar)')
# (786, 'Смесь сварочная (He + Ar)')
# (787, 'Смесь сварочная (СО2 + О2 + Ar)')
# (788, 'Смесь сварочная (СО2 + О2 + Ar)')
# (789, 'Смесь сварочная (СО2 + О2 + Ar)')
# (790, 'Смесь сварочная (СО2 + О2 + Ar)')
# (791, 'Смесь сварочная (СО2 + О2 + Ar)')
# (792, 'Смесь сварочная (СО2 + О2 + Ar)')
# (793, 'Смесь сварочная (Н2 <10% + Ar)')
# (794, 'Смесь сварочная (Н2 <10% + Ar)')
# (795, 'Смесь сварочная (Н2 <10% + Ar)')
# (796, 'Смесь сварочная (Н2 <10% + Ar)')
# (797, 'Смесь сварочная (Н2 <10% + Ar)')
# (798, 'Смесь сварочная (Н2 <10% + Ar)')
# (799, 'Смесь сварочная (О2 + СО2)')
# (800, 'Смесь сварочная (О2 + СО2)')
# (801, 'Смесь сварочная (О2 + Ar)')
# (802, 'Смесь сварочная (О2 + Ar)')
# (803, 'Смесь сварочная (2%СО2 + 98%Аr)')
# (804, 'Смесь сварочная (2%СО2 + 98%Аr)')
# (805, 'Смесь сварочная (2%СО2 + 98%Аr)')
# (806, 'Смесь сварочная (2%СО2 + 98%Аr)')
# (807, 'Смесь сварочная (2%СО2 + 98%Аr)')
# (808, 'Смесь сварочная (2%СО2 + 98%Аr)')
# (809, 'Смесь сварочная (5%СО2 + 95%Аr)')
# (810, 'Смесь сварочная (5%СО2 + 95%Аr)')
# (815, 'Смесь сварочная (8%СО2 + 92%Аr)')
# (816, 'Смесь сварочная (8%СО2 + 92%Аr)')
# (821, 'Смесь сварочная (10%СО2 + 90%Аr)')
# (822, 'Смесь сварочная (10%СО2 + 90%Аr)')
# (827, 'Смесь сварочная (18%СО2 + 82%Аr)')
# (828, 'Смесь сварочная (18%СО2 + 82%Аr)')
# (833, 'Смесь сварочная (20%СО2 + 80%Аr)')
# (834, 'Смесь сварочная (20%СО2 + 80%Аr)')
# (838, 'Смесь сварочная (20%СО2 + 80%Аr)')
# (839, 'Пищевая газовая смесь (20%CO2+80% N2) БИОГОН')
# (840, 'Пищевая газовая смесь (20%CO2+80% N2) БИОГОН')
# (841, 'Пищевая газовая смесь (20%CO2+80% N2) БИОГОН')
# (842, 'Пищевая газовая смесь (20%CO2+80% N2) БИОГОН')
# (843, 'Пищевая газовая смесь (30%CO2+70% N2) БИОГОН')
# (844, 'Пищевая газовая смесь (30%CO2+70% N2) БИОГОН')
# (845, 'Пищевая газовая смесь (30%CO2+70% N2) БИОГОН')
# (846, 'Пищевая газовая смесь (30%CO2+70% N2) БИОГОН')
# (847, 'Пищевая газовая смесь (N2+C2H4) БАНАНГАЗ')
# (848, 'Пищевая газовая смесь (N2+C2H4) БАНАНГАЗ')
# (849, 'Пищевая газовая смесь (N2+C2H4) БАНАНГАЗ')
# (850, 'Пищевая газовая смесь (N2+C2H4) БАНАНГАЗ')
# (851, 'Лазерный газ (He <40% + N2 + CO2)')
# (852, 'Лазерный газ (He <40% + N2 + CO2)')
# (853, 'Лазерный газ (He <40% + N2 + CO2)')
# (854, 'Лазерный газ (He <40% + N2 + CO2)')
# (855, 'Лазерный газ (He >40% + N2 + CO2)')
# (856, 'Лазерный газ (He >40% + N2 + CO2)')
# (859, 'Лазерный газ Двуокись углерода - азот (CO2 + N2)')
# (860, 'Лазерный газ Двуокись углерода - азот (CO2 + N2)')
# (862, 'Лазерный газ Двуокись углерода - азот (CO2 + N2)')
# (863, 'Газовая смесь для стерилизации Окись этилена + двуокись углерода (С2H4О + СО2)')
# (864, 'Газовая смесь для стерилизации Окись этилена + двуокись углерода (С2H4О + СО2)')
# (865, 'Смеси медицинского назначения, Анаэробная смесь двуокись углерода + азот (CO2+N2)')
# (866, 'Смеси медицинского назначения, Анаэробная смесь двуокись углерода + азот (CO2+N2)')
# (867, 'Смеси медицинского назначения, Анаэробная смесь двуокись углерода + азот (CO2+N2)')
# (868, 'Смеси медицинского назначения, Анаэробная смесь двуокись углерода + азот (CO2+N2)')
# (869, 'Смеси медицинского назначения, Анаэробная смесь водород + двуокись углерода (H2+CO2)')
# (870, 'Смеси медицинского назначения, Анаэробная смесь водород + двуокись углерода (H2+CO2)')
# (873, 'Смеси медицинского назначения, Анаэробная смесь двуокись углерода + водород + азот (CO2+H2+N2)')
# (874, 'Смеси медицинского назначения, Анаэробная смесь двуокись углерода + водород + азот (CO2+H2+N2)')
# (877, 'Смеси медицинского назначения, Ацетилен - кислород - азот (C2H2 + O2 + N2)')
# (878, 'Смеси медицинского назначения, Ацетилен - кислород - азот (C2H2 + O2 + N2)')
# (881, 'Смеси медицинского назначения, Гелий - кислород (He + O2)')
# (882, 'Смеси медицинского назначения, Гелий - кислород (He + O2)')
# (885, 'Смеси медицинского назначения, Двуокись углерода - кислород (карбоген) (CO2 + O2)')
# (886, 'Смеси медицинского назначения, Двуокись углерода - кислород (карбоген) (CO2 + O2)')
# (889, 'Смеси медицинского назначения, Двуокись углерода - кислород - азот (CO2 + O2 + N2)')
# (890, 'Смеси медицинского назначения, Двуокись углерода - кислород - азот (CO2 + O2 + N2)')
# (893, 'Смеси медицинского назначения, Окись азота - азот (NO + N2)')
# (894, 'Смеси медицинского назначения, Окись азота - азот (NO + N2)')
# (895, 'Смеси медицинского назначения, Дыхательная смесь CO+CH4+O2+N2')
# (896, 'Смеси медицинского назначения, Дыхательная смесь CO+CH4+O2+N2')
# (897, 'Смеси медицинского назначения, Дыхательная смесь CO+He+O2+N2')
# (898, 'Смеси медицинского назначения, Дыхательная смесь CO+He+O2+N2')
# (899, 'Смеси Технические (ТГС), Метан (0,1-4%) + азот/воздух')
# (900, 'Смеси Технические (ТГС), Метан (0,1-4%) + азот/воздух')
# (901, 'Смеси Технические (ТГС), Метан (0,1-4%) + азот/воздух')
# (902, 'Смеси Технические (ТГС), Метан (0,1-4%) + азот/воздух')
# (903, 'Смеси Технические (ТГС), Метан (4-20%) + азот')
# (904, 'Смеси Технические (ТГС), Метан (4-20%) + азот')
# (905, 'Смеси Технические (ТГС), Метан (4-20%) + азот')
# (906, 'Смеси Технические (ТГС), Метан (4-20%) + азот')
# (907, 'Смеси Технические (ТГС), Метан (> 20%) + азот')
# (908, 'Смеси Технические (ТГС), Метан (> 20%) + азот')
# (909, 'Смеси Технические (ТГС), Метан (> 20%) + азот')
# (910, 'Смеси Технические (ТГС), Метан (> 20%) + азот')
# (911, 'Смеси Технические (ТГС), Метан (< 15%) + аргон')
# (912, 'Смеси Технические (ТГС), Метан (< 15%) + аргон')
# (913, 'Смеси Технические (ТГС), Метан (< 15%) + аргон')
# (914, 'Смеси Технические (ТГС), Метан (< 15%) + аргон')
# (915, 'Смеси Технические (ТГС), Водород (0,01-1%) + азот/воздух')
# (916, 'Смеси Технические (ТГС), Водород (0,01-1%) + азот/воздух')
# (917, 'Смеси Технические (ТГС), Водород (0,01-1%) + азот/воздух')
# (918, 'Смеси Технические (ТГС), Водород (0,01-1%) + азот/воздух')
# (919, 'Смеси Технические (ТГС), Оксид углерода (0,1-1%) + азот/воздух')
# (920, 'Смеси Технические (ТГС), Оксид углерода (0,1-1%) + азот/воздух')
# (921, 'Смеси Технические (ТГС), Оксид углерода (0,1-1%) + азот/воздух')
# (922, 'Смеси Технические (ТГС), Оксид углерода (0,1-1%) + азот/воздух')
# (923, 'Смеси Технические (ТГС), Двуокись углерода (0,1-10%) + азот/воздух')
# (924, 'Смеси Технические (ТГС), Двуокись углерода (0,1-10%) + азот/воздух')
# (925, 'Смеси Технические (ТГС), Двуокись углерода (0,1-10%) + азот/воздух')
# (926, 'Смеси Технические (ТГС), Двуокись углерода (0,1-10%) + азот/воздух')
# (927, 'Смеси эксимерные, Аргон + гелий + неон (буфер) (Ar + He + Ne)')
# (928, 'Смеси эксимерные, Аргон + гелий + неон (буфер) (Ar + He + Ne)')
# (929, 'Смеси эксимерные, Фтор (5%) + гелий (F2 5% + He)')
# (930, 'Смеси эксимерные, Фтор (5%) + гелий (F2 5% + He)')
# (931, 'Смеси эксимерные, Фтор + аргон + гелий (VISX) (F2 + Ar + He)')
# (932, 'Смеси эксимерные, Фтор + аргон + гелий (VISX) (F2 + Ar + He)')
# (933, 'Смеси эксимерные, Фтор + аргон + гелий + неон (F2+Ar+He+Ne)')
# (934, 'Смеси эксимерные, Фтор + аргон + гелий + неон (F2+Ar+He+Ne)')
# (935, 'Смеси эксимерные, Фтор + аргон + неон (F2 + Ar + Ne)')
# (936, 'Смеси эксимерные, Фтор + аргон + неон (F2 + Ar + Ne)')
# (937, 'Смеси эксимерные, Фтор + криптон + неон (F2+Kr+Ne)')
# (938, 'Смеси эксимерные, Фтор + криптон + неон (F2+Kr+Ne)')
# (939, 'Припои специальные, Сплав Розе')
# (940, 'Припои специальные, Сплав Розе')
# (941, 'Припои специальные, Сплав Розе')
# (942, 'Припои специальные, Сплав Вуда')
# (943, 'Припои специальные, Сплав Вуда')
# (944, 'Припои специальные, Сплав Вуда')
# (945, 'Припои специальные, ПОВи 0,5')
# (950, 'Припои специальные, ПОИн 52')
# (951, 'Припои специальные, ПОИн 52')
# (952, 'Припои специальные, ПОИн 52')
# (953, 'Припои специальные, ПОСу 95-5')
# (958, 'Припои с содержанием олова, П200А (ПОЦ 10)')
# (960, 'Припои с содержанием олова, П200А (ПОЦ 10)')
# (963, 'Припои с содержанием олова, П200А (ПОЦ 10)')
# (964, 'Припои с содержанием олова, П 250А (ПОЦ 80/20)')
# (966, 'Припои с содержанием олова, ПОЦ 60/40')
# (968, 'Припои с содержанием олова, ПОЦ 50')
# (970, 'Медно-фосфористые припои, ПМФОЦр 6-4-0,03')
# (972, 'Медно-фосфористые припои, ПМФОЦр 6-4-0,03 с флюсом')
# (973, 'Медно-фосфористые припои, П14')
# (976, 'Медно-фосфористые припои, П14 с флюсом')
# (977, 'Медно-фосфористые припои, П81')
# (979, 'Медно-фосфористые припои, ПМФ 7')
# (981, 'Медно-фосфористые припои, ПМФ 7')
# (982, 'Медно-фосфористые припои, ПМФ 9')
# (984, 'Медно-цинковые припои, Л63')
# (988, 'Медно-цинковые припои, Л63')
# (989, 'Медно-цинковые припои, ЛК 62-05')
# (992, 'Медно-цинковые припои, ЛОК 59-1-0,3')
# (995, 'Медно-цинковые припои, П47')
# (996, 'Припои таблетированные, П100м')
# (997, 'Припои таблетированные, Л 63')
# (998, 'Припои для пайки твердосплавного металлорежущего инструмента, МНМц 68-4-2')
# (999, 'Припои для пайки твердосплавного металлорежущего инструмента, МНМц 68-4-2')
# (1000, 'Припои для пайки твердосплавного металлорежущего инструмента, АНМц 0,6-4-2')
# (1001, 'Припои для пайки твердосплавного металлорежущего инструмента, ЛМцЖ 57-1,5-0,75')
# (1002, 'Припои для пайки твердосплавного металлорежущего инструмента, ЛНКоМц 49-9-0,2-0,2')
# (1003, 'Припои для пайки твердосплавного металлорежущего инструмента, ЛНМц 49-9-0,2')
# (1004, 'Припои для пайки твердосплавного металлорежущего инструмента, ТП-1М')
# (1005, 'Припои для пайки алюминия, Припой 34А')
# (1006, 'Припои для пайки алюминия, Припой 35А')
# (1007, 'Припои для пайки алюминия, Припой 19А')
# (1008, 'Припои для пайки алюминия, Припой 20А')
# (1009, 'Припои, Олово, О1 пч, О1')
# (1010, 'Припои, Олово, О1 пч, О1')
# (1011, 'Припои, Олово, О1 пч, О1')
# (1013, 'Припои, Олово, О1 пч, О1')
# (1014, 'Припои, Олово, О1 пч, О1')
# (1015, 'Припои, Олово, О1 пч, О1')
# (1016, 'Припои, Олово, О1 пч, О1')
# (1017, 'Припои, Олово, О1 пч, О1')
# (1018, 'Припои, Олово, О1 пч, О1')
# (1019, 'Припои, Олово, О1 пч, О1')
# (1020, 'Припои, Олово, О1 пч, О1')
# (1021, 'Припои, Олово, О1 пч, О1')
# (1022, 'Припои малосурьмянистые, ПОССу-61-0,5')
# (1023, 'Припои малосурьмянистые, ПОССу-61-0,5')
# (1024, 'Припои малосурьмянистые, ПОССу-61-0,5')
# (1025, 'Припои малосурьмянистые, ПОССу-61-0,5')
# (1026, 'Припои малосурьмянистые, ПОССу-61-0,5')
# (1027, 'Припои малосурьмянистые, ПОССу-61-0,5')
# (1028, 'Припои малосурьмянистые, ПОССу-61-0,5')
# (1029, 'Припои малосурьмянистые, ПОССу-61-0,5')
# (1030, 'Припои малосурьмянистые, ПОССу-61-0,5')
# (1031, 'Припои малосурьмянистые, ПОССу-61-0,5')
# (1032, 'Припои малосурьмянистые, ПОССу-61-0,5')
# (1033, 'Припои малосурьмянистые, ПОССу-61-0,5')
# (1034, 'Припои малосурьмянистые, ПОССу-61-0,5')
# (1035, 'Припои малосурьмянистые, ПОССу-50-0,5')
# (1036, 'Припои малосурьмянистые, ПОССу-50-0,5')
# (1037, 'Припои малосурьмянистые, ПОССу-50-0,5')
# (1038, 'Припои малосурьмянистые, ПОССу-50-0,5')
# (1039, 'Припои малосурьмянистые, ПОССу-50-0,5')
# (1040, 'Припои малосурьмянистые, ПОССу-50-0,5')
# (1041, 'Припои малосурьмянистые, ПОССу-50-0,5')
# (1042, 'Припои малосурьмянистые, ПОССу-50-0,5')
# (1043, 'Припои малосурьмянистые, ПОССу-50-0,5')
# (1044, 'Припои малосурьмянистые, ПОССу-50-0,5')
# (1045, 'Припои малосурьмянистые, ПОССу-50-0,5')
# (1046, 'Припои малосурьмянистые, ПОССу-50-0,5')
# (1047, 'Припои малосурьмянистые, ПОССу-50-0,5')
# (1048, 'Припои малосурьмянистые, ПОССу-40-0,5')
# (1049, 'Припои малосурьмянистые, ПОССу-40-0,5')
# (1050, 'Припои малосурьмянистые, ПОССу-40-0,5')
# (1051, 'Припои малосурьмянистые, ПОССу-40-0,5')
# (1052, 'Припои малосурьмянистые, ПОССу-40-0,5')
# (1053, 'Припои малосурьмянистые, ПОССу-40-0,5')
# (
# (1211, 'Припои бессурьмянистые, ПОС-30')
# (1212, 'Припои бессурьмянистые, ПОС-30')
# (1214, 'Припои бессурьмянистые, ПОС-30')
# (1215, 'Припои бессурьмянистые, ПОС-30')
# (1216, 'Припои бессурьмянистые, ПОС-30')
# (1217, 'Припои бессурьмянистые, ПОС-63')
# (1218, 'Припои бессурьмянистые, ПОС-63')
# (1219, 'Припои бессурьмянистые, ПОС-63')
# (1220, 'Припои бессурьмянистые, ПОС-63')
# (1221, 'Припои бессурьмянистые, ПОС-63')
# (1222, 'Припои бессурьмянистые, ПОС-63')
# (1223, 'Припои бессурьмянистые, ПОС-63')
# (1224, 'Припои бессурьмянистые, ПОС-63')
# (1225, 'Припои бессурьмянистые, ПОС-63')
# (1226, 'Припои бессурьмянистые, ПОС-63')
# (1227, 'Припои бессурьмянистые, ПОС-63')
# (1228, 'Припои бессурьмянистые, ПОС-63')
# ...
# (1950, 'Баллон для аргона 5 л, бесшовный, пустой')
# (1951, 'Газовый баллон 10 литров для сварочной смеси')
# (1952, 'Термо-чехол для газового баллона 18 л')
# (1953, 'Газовый баллон 10 литров для аргона')
# (1954, 'Газовый баллон для аргона 10 л')
# (1955, 'Баллон газовый для азота 10 л (d-133 мм), бесшовный, пустой')
# (1956, 'Газовый баллон 10 литров для сварочной смеси')
# (1957, 'Баллон углекислотный бесшовный, 2 л')
# (1958, 'Газовый баллон 10 литров для углекислоты')
# (1959, 'Шкаф для 1 газового баллона на 50 л серый')
# (1960, 'Газовый баллон 10 литров для ацетилена')
# (1961, 'Газовый баллон для углекислоты 10 л')
# (1962, 'Баллон для углекислоты, 10 л, бесшовный, пустой')
# (1963, 'Баллон для сварочной смеси, 10л бесшовный, пустой')
# (1964, 'Баллон для сварочной смеси, 10 л, сварной, пустой')
# (1965, 'Баллон для аргона, 10 л бесшовный, пустой')
# (1966, 'Баллон газовый углекислотный 10 л, бесшовный, пустой')
# (1967, 'Баллон углекислотный 5 литров бесшовный')
# (1968, 'Баллон для аргона, 1 л, бесшовный, пустой')
# (1969, 'Баллон для кислорода, 1 л, бесшовный, пустой')
# (1970, 'Газовый баллон 10 литров для кислорода')
# (1971, 'Переносной сварочный пост ПГСП-2 0.5-К(кислород 2л MAPP-газ)')
# (1972, 'Баллон для углекислоты 5 л, бесшовный, пустой')
# (1973, 'Баллон для кислорода, 2 л, бесшовный, пустой')
# (1974, 'Баллон для аргона, 10 л, сварной, пустой')
# (1975, 'Термо-чехол для газового баллона 24 л')
# (1976, 'Газовый баллончик СО2 для пневматики 12 г, 10 шт')
# (1977, 'Баллон для углекислоты, 10 л, сварной, пустой')
# (1978, 'Баллон для аргона 5 л, бесшовный, пустой')
# (1979, 'Баллон для азота 5 л, бесшовный, пустой')
# (1980, 'Баллон для углекислоты, 1 л, бесшовный, пустой')
# (1981, 'Баллон для кислорода, 10 л бесшовный, пустой')
# (1982, 'Баллон азотный 10л шовный')
# (1983, 'Баллон для азота, 10 л, бесшовный, пустой')
# (1984, 'Термо-чехол для газового баллона 12 л')
# (2234, 'Tricapil 5% SOFT Сыворотка для роста волос, 50 мл')
# (2235, 'Маска для волос с перцем Активатор роста 500мл')

# %%
data['Категория'].unique()
# Out:
# array(['Газы и газовые смеси', 'Промышленные технологии', 'Косметика',
#        'Герметики', 'Клеи и строительные смеси',
#        'Сварочные материалы и оборудование'], dtype=object)

# %%
import random
def data_discount_settings(row):
    category = row['Категория']
    price = row['Цена']
    if not pd.isna(row['Скидочная Цена']):
        return row['Скидочная Цена']
    if category == 'Газы и газовые смеси':
        discounts = range(3,11)
        return round(price - price * (random.choice(discounts)/100))
    if category == 'Промышленные технологии':
        discounts = range(5,16)
        return round(price - price * (random.choice(discounts)/100))
    if category == 'Косметика':
        discounts = range(5,26)
        return round(price - price * (random.choice(discounts)/100))
    if category == 'Герметики':
        discounts = range(10,21)
        return round(price - price * (random.choice(discounts)/100))
    if category == 'Клеи и строительные смеси':
        discounts = range(10,31)
        return round(price - price * (random.choice(discounts)/100))
    if category == 'Сварочные материалы и оборудование':
        discounts = range(5,21)
        return round(price - price * (random.choice(discounts)/100))
    return row['Скидочная Цена']
data['Скидочная Цена'] = data.apply(data_discount_settings, axis = 1, result_type = 'expand')

# %%
data.isna().mean()
# Out:
# Компания             0.0
# Категория            0.0
# Название товара      0.0
# Цена                 0.0
# Скидочная Цена       0.0
# Объем                0.0
# Единицы Измерения    0.0
# dtype: float64

# %%
data.to_csv(FOLDER_PATH +'chemical_5_companies_preprocessed.csv')
data.to_excel(FOLDER_PATH +'chemical_5_companies_preprocessed.xlsx')

# %%
data['Категория'].unique()
# Out:
# array(['Газы и газовые смеси', 'Промышленные технологии', 'Косметика',
#        'Герметики', 'Клеи и строительные смеси',
#        'Сварочные материалы и оборудование'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2061 entries, 0 to 2235
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Компания           2061 non-null   object
#  1   Категория          2061 non-null   object
#  2   Название товара    2061 non-null   object
#  3   Цена               2061 non-null   float64
#  4   Скидочная Цена     2061 non-null   float64
#  5   Объем              2061 non-null   float64
#  6   Единицы Измерения  2061 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 128.8+ KB

# %% [markdown]
# ## Генерация истории цен

# %%
# Генерация истории цен на основе Индексов цен с января 2020 по октябрь 2025
# Индексы взяты от раздела "Производство химических веществ и химических продуктов" с Росстата 

monthly_indexes = {
    # 2024-2025 (октябрь 2024 → октябрь 2025)
    '2025-01': 103.01, '2025-02': 101.60, '2025-03': 102.41, '2025-04': 99.23,
    '2025-05': 97.14, '2025-06': 95.80, '2025-07': 101.33, '2025-08': 96.05,
    '2025-09': 101.42, '2025-10': 101.04,
    
    # 2023-2024 
    '2024-01': 98.64, '2024-02': 98.61, '2024-03': 102.22, '2024-04': 101.75,
    '2024-05': 101.00, '2024-06': 99.54, '2024-07': 99.94, '2024-08': 100.65,
    '2024-09': 101.13, '2024-10': 100.62, '2024-11': 100.18, '2024-12': 100.76,
    
    # 2022-2023
    '2023-01': 100.56, '2023-02': 100.48, '2023-03': 99.73, '2023-04': 100.94,
    '2023-05': 101.78, '2023-06': 97.88, '2023-07': 100.09, '2023-08': 102.32,
    '2023-09': 103.45, '2023-10': 101.96, '2023-11': 100.74, '2023-12': 97.93,
    
    # 2021-2022
    '2022-01': 104.83, '2022-02': 100.84, '2022-03': 103.97, '2022-04': 105.57,
    '2022-05': 102.56, '2022-06': 95.42, '2022-07': 92.71, '2022-08': 94.53,
    '2022-09': 93.91, '2022-10': 97.07, '2022-11': 97.90, '2022-12': 98.68,
    
    # 2020-2021
    '2021-01': 103.47, '2021-02': 104.48, '2021-03': 105.45, '2021-04': 107.53,
    '2021-05': 106.88, '2021-06': 102.09, '2021-07': 101.06, '2021-08': 101.62,
    '2021-09': 100.86, '2021-10': 101.74, '2021-11': 104.25, '2021-12': 102.90,
}

def get_previous_month(month_str):
    """Получить предыдущий месяц в формате YYYY-MM"""
    year, month = map(int, month_str.split('-'))
    if month == 1:
        return f"{year-1}-12"
    else:
        return f"{year}-{month-1:02d}"
def calculate_chain_prices(current_price, start_month='2025-10', months_back=60):
    """
    Рассчитывает цены назад по цепочке месяцев
    """
    prices = {}
    current_price_float = current_price
    
    # Текущий месяц
    prices[start_month] = current_price_float
    current = start_month
    
    # Идем назад по месяцам
    for i in range(months_back):
        prev_month = get_previous_month(current)
        
        if prev_month in monthly_indexes:
            # Цена предыдущего месяца = текущая цена / индекс
            index = monthly_indexes[current] / 100  # индекс для перехода current → prev
            current_price_float = current_price_float / index
            prices[prev_month] = current_price_float
            current = prev_month
        else:
            break
    
    return prices
current_price = 1000  # Цена в октябре 2025
historical_prices = calculate_chain_prices(current_price)

# %%
historical_prices
# Out:
# {'2025-10': 1000,
#  '2025-09': 989.7070467141726,
#  '2025-08': 975.8499770402018,
#  '2025-07': 1015.9812358565349,
#  '2025-06': 1002.6460434782738,
#  '2025-05': 1046.603385676695,
#  '2025-04': 1077.4175269473903,
#  '2025-03': 1085.7780176835536,
#  '2025-02': 1060.2265576443253,
#  '2025-01': 1043.5300764215801,
#  '2024-12': 1013.0376433565481,
#  '2024-11': 1005.396628976328,
#  '2024-10': 1003.5901666763106,
#  '2024-09': 997.4062479390882,
#  '2024-08': 986.2614930674264,
#  '2024-07': 979.8921938076766,
#  '2024-06': 980.4804820969348,
#  '2024-05': 985.0115351586646,
#  '2024-04': 975.2589457016481,
#  '2024-03': 958.48545032103,
#  '2024-02': 937.6691942095774,
#  '2024-01': 950.8865167930002,
#  '2023-12': 963.9968742832524,
#  '2023-11': 984.3734037406845,
#  '2023-10': 977.1425488789802,
#  '2023-09': 958.3587180060615,
#  '2023-08': 926.3979874394022,
#  '2023-07': 905.392872790659,
#  '2023-06': 904.5787519139363,
#  '2023-05': 924.171180950078,
#  '2023-04': 908.0086273826665,
#  '2023-03': 899.5528307733965,
#  '2023-02': 901.9881989104547,
#  '2023-01': 897.6793380876339,
#  '2022-12': 892.680328249437,
#  '2022-11': 904.6213298028343,
#  '2022-10': 924.025873138748,
#  '2022-09': 951.917042483515,
#  '2022-08': 1013.648219021952,
#  '2022-07': 1072.3032042969976,
#  '2022-06': 1156.6208653834512,
#  '2022-05': 1212.1367275030927,
#  '2022-04': 1181.880584538897,
#  '2022-03': 1119.5231453432766,
#  '2022-02': 1076.7751710524926,
#  '2022-01': 1067.8056039790686,
#  '2021-12': 1018.6068911371444,
#  '2021-11': 989.8997970234639,
#  '2021-10': 949.54416980668,
#  '2021-09': 933.3046685735012,
#  '2021-08': 925.3466870647444,
#  '2021-07': 910.5950472985086,
#  '2021-06': 901.0439810988607,
#  '2021-05': 882.5976893905971,
#  '2021-04': 825.7837662711426,
#  '2021-03': 767.9566318898378,
#  '2021-02': 728.266127918291,
#  '2021-01': 697.0387901208758}

# %%
def create_quarterly_features(historical_prices):
    """
    Создает квартальные фичи на основе месячных данных
    Берет последний месяц каждого квартала
    """
    quarterly_features = {}
    
    # Отбираем конечные месяцы кварталов
    quarter_months = {
        'Q1': '03',  # март
        'Q2': '06',  # июнь
        'Q3': '09',  # сентябрь
        'Q4': '12'   # декабрь
    }
    
    for month, price in historical_prices.items():
        year, month_num = month.split('-')
        
        # Проверяем, является ли месяц конечным в квартале
        for quarter, end_month in quarter_months.items():
            if month_num == end_month:
                feature_name = f'Цена_{quarter}_{year}'
                quarterly_features[feature_name] = round(price, 2)
    
    return quarterly_features

# Создаем квартальные фичи
quarterly_features = create_quarterly_features(historical_prices)
print(quarterly_features)
# Out:
# {'Цена_Q3_2025': 989.71, 'Цена_Q2_2025': 1002.65, 'Цена_Q1_2025': 1085.78, 'Цена_Q4_2024': 1013.04, 'Цена_Q3_2024': 997.41, 'Цена_Q2_2024': 980.48, 'Цена_Q1_2024': 958.49, 'Цена_Q4_2023': 964.0, 'Цена_Q3_2023': 958.36, 'Цена_Q2_2023': 904.58, 'Цена_Q1_2023': 899.55, 'Цена_Q4_2022': 892.68, 'Цена_Q3_2022': 951.92, 'Цена_Q2_2022': 1156.62, 'Цена_Q1_2022': 1119.52, 'Цена_Q4_2021': 1018.61, 'Цена_Q3_2021': 933.3, 'Цена_Q2_2021': 901.04, 'Цена_Q1_2021': 767.96}

# %%
# Определяем порядок кварталов (от новых к старым)
quarters_order = [
        'Цена_Q3_2025', 'Цена_Q2_2025', 'Цена_Q1_2025',
        'Цена_Q4_2024', 'Цена_Q3_2024', 'Цена_Q2_2024', 'Цена_Q1_2024', 
        'Цена_Q4_2023', 'Цена_Q3_2023', 'Цена_Q2_2023', 'Цена_Q1_2023',
        'Цена_Q4_2022', 'Цена_Q3_2022', 'Цена_Q2_2022', 'Цена_Q1_2022',
        'Цена_Q4_2021', 'Цена_Q3_2021', 'Цена_Q2_2021', 'Цена_Q1_2021'
    ]

# Определяем уровень волатильности для каждой категории

'''
Обоснование уровней волатильности:

Высокая волатильность (6-8%):

Газы и газовые смеси (8%) - сильно зависят от цен на энергоносители, сырьевые рынки, логистики
Клеи и строительные смеси (7%) - тесно связаны со строительным циклом, сезонностью спроса
Средняя волатильность (4-6%):

Герметики (6%) - зависимость от строительного рынка, но более стабильный спрос
Промышленные технологии (5%) - B2B сегмент с долгосрочными контрактами
Низкая волатильность (3-4%):

Косметика (3%) - потребительские товары с устойчивым спросом, брендовая лояльность
Сварочные материалы (4%) - промышленное применение, но специализированный спрос
'''

category_noise = {
    'Газы и газовые смеси': (0.95, 1.10),       # -5% до +10% - высокая волатильность
    'Промышленные технологии': (0.98, 1.07),    # -2% до +7% - средняя волатильность  
    'Косметика': (0.99, 1.05),                  # -1% до +5% - низкая волатильность
    'Герметики': (0.97, 1.08),                  # -3% до +8% - средняя волатильность
    'Клеи и строительные смеси': (0.96, 1.09),  # -4% до +9% - высокая волатильность
    'Сварочные материалы и оборудование': (0.98, 1.06),  # -2% до +6% - низкая волатильность
}


def calculate_quarterly_tuple(row):
    """
    Функция для apply, возвращает кортеж квартальных цен
    """
    current_price = row['Цена']
    current_category = row['Категория']
    current_noise = category_noise.get(current_category, (0.97, 1.05))
    
    historical_prices = calculate_chain_prices(current_price)
    quarterly_features = create_quarterly_features(historical_prices)
    
    quarterly_features_noise = {}
    for quarter, price in quarterly_features.items():
        noise = np.random.uniform(current_noise[0], current_noise[1])
        price_with_noise = price * noise
        quarterly_features_noise[quarter] = round(price_with_noise)
    
    # Создаем кортеж значений в нужном порядке
    values_tuple = tuple(
        quarterly_features_noise.get(quarter, None)
        for quarter in quarters_order)
    
    return values_tuple

quarters_prices = data.apply(calculate_quarterly_tuple, axis = 1, result_type = 'expand')
quarters_prices_pd = pd.DataFrame(quarters_prices)
quarters_prices_pd = quarters_prices_pd.rename(columns = {i: col for i,col in enumerate(quarters_order)})

# %%
quarters_prices_pd
# Out:
#       Цена_Q3_2025  Цена_Q2_2025  Цена_Q1_2025  Цена_Q4_2024  Цена_Q3_2024  \
# 0              805           928           924           881           920
# 1             1174          1199          1350          1172          1284
# 2             3380          3106          3372          3418          3036
# 3             2156          2343          2446          2135          2094
# 4             4797          4839          4678          4687          4490
# ...            ...           ...           ...           ...           ...
# 2231           887           900           941           903           863
# 2232           930           945          1047           947           965
# 2233          6542          6392          7108          6484          6547
# 2234          3638          3649          3929          3663          3659
# 2235           443           450           496           470           462
#
#       Цена_Q2_2024  Цена_Q1_2024  Цена_Q4_2023  Цена_Q3_2023  Цена_Q2_2023  \
# 0              795           896           883           845           833
# 1             1162          1125          1258          1112          1148
# 2             3100          3144          3345          3317          2811
# 3             2270          2008          2304          2079          2108
# 4             4302          4527          4231          4686          3957
# ...            ...           ...           ...           ...           ...
# 2231           867           848           859           848           789
# 2232           940           922           903           922           872
# 2233          6342          6109          6319          6072          5750
# 2234          3562          3544          3509          3564          3270
# 2235           434           425           446           433           411
#
#       Цена_Q1_2023  Цена_Q4_2022  Цена_Q3_2022  Цена_Q2_2022  Цена_Q1_2022  \
# 0              791           783           887          1004           996
# 1             1048          1141          1169          1453          1415
# 2             3157          2980          2924          4014          3737
# 3             2164          1943          1992          2461          2541
# 4             4247          4245          4278          5047          5491
# ...            ...           ...           ...           ...           ...
# 2231           766           777           819          1020           956
# 2232           857           831           873          1093          1046
# 2233          5765          5958          6328          7592          7424
# 2234          3263          3272          3480          4327          4045
# 2235           404           403           437           528           511
#
#       Цена_Q4_2021  Цена_Q3_2021  Цена_Q2_2021  Цена_Q1_2021
# 0              911           845           730           648
# 1             1172          1180          1123           974
# 2             3136          3085          2796          2456
# 3             2432          2034          2104          1683
# 4             4622          4514          3908          3380
# ...            ...           ...           ...           ...
# 2231           874           815           775           679
# 2232           950           882           828           729
# 2233          6636          6256          5820          5019
# 2234          3785          3411          3366          2906
# 2235           475           420           418           358
#
# [2061 rows x 19 columns]

# %%
data.columns
# Out:
# Index(['Компания', 'Категория', 'Название товара', 'Цена', 'Скидочная Цена',
#        'Объем', 'Единицы Измерения'],
#       dtype='object')

# %%
data = pd.concat([data, quarters_prices_pd], axis = 1)

# %%
data_example = data.loc[0,['Цена_Q3_2025', 'Цена_Q2_2025',
       'Цена_Q1_2025', 'Цена_Q4_2024', 'Цена_Q3_2024', 'Цена_Q2_2024',
       'Цена_Q1_2024', 'Цена_Q4_2023', 'Цена_Q3_2023', 'Цена_Q2_2023',
       'Цена_Q1_2023', 'Цена_Q4_2022', 'Цена_Q3_2022', 'Цена_Q2_2022',
       'Цена_Q1_2022', 'Цена_Q4_2021', 'Цена_Q3_2021', 'Цена_Q2_2021',
       'Цена_Q1_2021']]
import plotly.express as px
fig = px.line(y = data_example[::-1], x = data_example.index[::-1])
fig.show()

# %%
data
# Out:
#                    Компания             Категория  \
# 0          АЛТАЙСТРОЙДЕТАЛЬ  Газы и газовые смеси
# 1          АЛТАЙСТРОЙДЕТАЛЬ  Газы и газовые смеси
# 2          АЛТАЙСТРОЙДЕТАЛЬ  Газы и газовые смеси
# 3          АЛТАЙСТРОЙДЕТАЛЬ  Газы и газовые смеси
# 4          АЛТАЙСТРОЙДЕТАЛЬ  Газы и газовые смеси
# ...                     ...                   ...
# 2231  ISKARTES Professional             Косметика
# 2232                MATRIZA             Косметика
# 2233                  vichy             Косметика
# 2234               Cosmokey             Косметика
# 2235             Compliment             Косметика
#
#                                         Название товара    Цена  \
# 0     КИСЛОРОД газообразный технический ГОСТ 5583-78...   850.0
# 1       Кислород газообразный медицинский ФСП ЛП-001553  1200.0
# 2                        Кислород особой чистоты 99,99%  3200.0
# 3                              Азот / Двуокись углерода  2200.0
# 4              Кислород жидкий технический ГОСТ 6331-78  4500.0
# ...                                                 ...     ...
# 2231       Маска для роста волос с острым перцем 500 мл   858.0
# 2232      Сыворотка для роста волос несмываемая, 100 мл   922.0
# 2233  DERCOS DENSI-SOLUTIONS Сыворотка для роста вол...  6389.0
# 2234  Tricapil 5% SOFT Сыворотка для роста волос, 50 мл  3628.0
# 2235     Маска для волос с перцем Активатор роста 500мл   446.0
#
#       Скидочная Цена  Объем Единицы Измерения  Цена_Q3_2025  Цена_Q2_2025  \
# 0              782.0  40.00              литр           805           928
# 1             1092.0  10.00              литр          1174          1199
# 2             3040.0  40.00              литр          3380          3106
# 3             2024.0  20.00              литр          2156          2343
# 4             4320.0  50.00              литр          4797          4839
# ...              ...    ...               ...           ...           ...
# 2231           344.0   0.50              литр           887           900
# 2232           616.0   0.10              литр           930           945
# 2233          4536.0   0.10              литр          6542          6392
# 2234          1043.0   0.05              литр          3638          3649
# 2235           313.0   0.50              литр           443           450
#
#       Цена_Q1_2025  ...  Цена_Q2_2023  Цена_Q1_2023  Цена_Q4_2022  \
# 0              924  ...           833           791           783
# 1             1350  ...          1148          1048          1141
# 2             3372  ...          2811          3157          2980
# 3             2446  ...          2108          2164          1943
# 4             4678  ...          3957          4247          4245
# ...            ...  ...           ...           ...           ...
# 2231           941  ...           789           766           777
# 2232          1047  ...           872           857           831
# 2233          7108  ...          5750          5765          5958
# 2234          3929  ...          3270          3263          3272
# 2235           496  ...           411           404           403
#
#       Цена_Q3_2022  Цена_Q2_2022  Цена_Q1_2022  Цена_Q4_2021  Цена_Q3_2021  \
# 0              887          1004           996           911           845
# 1             1169          1453          1415          1172          1180
# 2             2924          4014          3737          3136          3085
# 3             1992          2461          2541          2432          2034
# 4             4278          5047          5491          4622          4514
# ...            ...           ...           ...           ...           ...
# 2231           819          1020           956           874           815
# 2232           873          1093          1046           950           882
# 2233          6328          7592          7424          6636          6256
# 2234          3480          4327          4045          3785          3411
# 2235           437           528           511           475           420
#
#       Цена_Q2_2021  Цена_Q1_2021
# 0              730           648
# 1             1123           974
# 2             2796          2456
# 3             2104          1683
# 4             3908          3380
# ...            ...           ...
# 2231           775           679
# 2232           828           729
# 2233          5820          5019
# 2234          3366          2906
# 2235           418           358
#
# [2061 rows x 26 columns]

# %%
data = data.reset_index(drop = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2061 entries, 0 to 2060
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Компания           2061 non-null   object
#  1   Категория          2061 non-null   object
#  2   Название товара    2061 non-null   object
#  3   Цена               2061 non-null   float64
#  4   Скидочная Цена     2061 non-null   float64
#  5   Объем              2061 non-null   float64
#  6   Единицы Измерения  2061 non-null   object
#  7   Цена_Q3_2025       2061 non-null   int64
#  8   Цена_Q2_2025       2061 non-null   int64
#  9   Цена_Q1_2025       2061 non-null   int64
#  10  Цена_Q4_2024       2061 non-null   int64
#  11  Цена_Q3_2024       2061 non-null   int64
#  12  Цена_Q2_2024       2061 non-null   int64
#  13  Цена_Q1_2024       2061 non-null   int64
#  14  Цена_Q4_2023       2061 non-null   int64
#  15  Цена_Q3_2023       2061 non-null   int64
#  16  Цена_Q2_2023       2061 non-null   int64
#  17  Цена_Q1_2023       2061 non-null   int64
#  18  Цена_Q4_2022       2061 non-null   int64
#  19  Цена_Q3_2022       2061 non-null   int64
#  20  Цена_Q2_2022       2061 non-null   int64
#  21  Цена_Q1_2022       2061 non-null   int64
#  22  Цена_Q4_2021       2061 non-null   int64
#  23  Цена_Q3_2021       2061 non-null   int64
#  24  Цена_Q2_2021       2061 non-null   int64
#  25  Цена_Q1_2021       2061 non-null   int64
# dtypes: float64(3), int64(19), object(4)
# memory usage: 418.8+ KB

# %%
data.to_csv(FOLDER_PATH + 'total_data_for_analysis.csv')
